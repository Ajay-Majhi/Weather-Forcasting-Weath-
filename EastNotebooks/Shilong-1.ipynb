# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import scipy.stats as stats
from sklearn import metrics
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn import metrics
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import xgboost as xgb
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import joblib

# %%
df = pd.read_csv("Shilong-1.csv")

# %%
df
# Out:
#       Unnamed: 0    T2M  PRECTOTCORR  DY  MO  YEAR   RH2M   WD50M  WS2M
# 0              0  11.65          0.0   1   1  2011  90.44  239.00  1.61
# 1              1  10.69          1.0   2   1  2011  86.12  208.19  0.99
# 2              2  11.40          1.0   3   1  2011  84.50  139.88  0.98
# 3              3  10.40          1.0   4   1  2011  83.25  136.19  1.02
# 4              4  10.59          1.0   5   1  2011  84.44  140.56  1.24
# ...          ...    ...          ...  ..  ..   ...    ...     ...   ...
# 3738        3738  20.42          1.0  27   3  2021  35.88  272.69  1.44
# 3739        3739  21.01          1.0  28   3  2021  39.12  268.94  1.48
# 3740        3740  20.71          0.0  29   3  2021  56.69  209.06  1.39
# 3741        3741  19.64          0.0  30   3  2021  81.12  168.81  1.54
# 3742        3742  20.21          0.0  31   3  2021  83.06  175.75  1.89
#
# [3743 rows x 9 columns]

# %%
d=df.drop(['Unnamed: 0'],axis=1)

# %%
df=d.copy()

# %%
X = df.drop(["PRECTOTCORR", "DY","MO","YEAR","RH2M","WS2M",'WD50M'], axis=1)
Y = df["PRECTOTCORR"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, stratify = Y, random_state = 0)

# %%
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
# Out:
# array([0.2988301])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# T2M    0.29883
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(2, 1))
# Out:
# <AxesSubplot:>

# %%
sm = SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# The number of classes before fit Counter({0.0: 1947, 1.0: 1047})
# The number of classes after fit Counter({0.0: 1947, 1.0: 1947})

# %%
logreg = LogisticRegression()
logreg.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression()

# %%
y_pred2 = logreg.predict(X_test)
print(confusion_matrix(y_test,y_pred2))
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[404  83]
#  [ 57 205]]
# 0.8130841121495327
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.83      0.85       487
#          1.0       0.71      0.78      0.75       262
#
#     accuracy                           0.81       749
#    macro avg       0.79      0.81      0.80       749
# weighted avg       0.82      0.81      0.81       749

# %%
metrics.plot_roc_curve(logreg, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred2, average=None)
# Out:
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.8060057682963149

# %%
gnb = GaussianNB()
gnb.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_pred3 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(accuracy_score(y_test,y_pred3))
print(classification_report(y_test,y_pred3))
# Out:
# [[411  76]
#  [ 61 201]]
# 0.8170894526034713
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.84      0.86       487
#          1.0       0.73      0.77      0.75       262
#
#     accuracy                           0.82       749
#    macro avg       0.80      0.81      0.80       749
# weighted avg       0.82      0.82      0.82       749

# %%
metrics.plot_roc_curve(gnb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred3, average=None)
# Out:
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.8055590388262772

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_res, y_train_res)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred4 = knn.predict(X_test)
print(confusion_matrix(y_test,y_pred4))
print(accuracy_score(y_test,y_pred4))
print(classification_report(y_test,y_pred4))
# Out:
# [[391  96]
#  [ 58 204]]
# 0.794392523364486
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.80      0.84       487
#          1.0       0.68      0.78      0.73       262
#
#     accuracy                           0.79       749
#    macro avg       0.78      0.79      0.78       749
# weighted avg       0.80      0.79      0.80       749
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.metrics import RocCurveDisplay

# %%
metrics.plot_roc_curve(knn, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred4, average=None)
# Out:
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.790750348762481

# %%
svc = SVC()

# %%
svc.fit(X_train_res, y_train_res)
# Out:
# SVC()

# %%
y_pred5 = svc.predict(X_test)
print(confusion_matrix(y_test,y_pred5))
print(accuracy_score(y_test,y_pred5))
print(classification_report(y_test,y_pred5))
# Out:
# [[381 106]
#  [ 39 223]]
# 0.8064085447263017
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.78      0.84       487
#          1.0       0.68      0.85      0.75       262
#
#     accuracy                           0.81       749
#    macro avg       0.79      0.82      0.80       749
# weighted avg       0.83      0.81      0.81       749

# %%
metrics.plot_roc_curve(svc, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred5, average=None)
# Out:
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.8167429502954684

# %%
# create model instance
bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# fit model
bst.fit(X_train, y_train)
# make predictions
y_pred6 = bst.predict(X_test)

# %%
# y_pred6 = xgb.predict(X_test)
print(confusion_matrix(y_test,y_pred6))
print(accuracy_score(y_test,y_pred6))
print(classification_report(y_test,y_pred6))
# Out:
# [[398  89]
#  [ 52 210]]
# 0.8117489986648865
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.82      0.85       487
#          1.0       0.70      0.80      0.75       262
#
#     accuracy                           0.81       749
#    macro avg       0.79      0.81      0.80       749
# weighted avg       0.82      0.81      0.81       749

# %%
rf=RandomForestClassifier()
rf.fit(X_train_res,y_train_res)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = rf.predict(X_test)
print(confusion_matrix(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# [[394  93]
#  [ 75 187]]
# 0.7757009345794392
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.81      0.82       487
#          1.0       0.67      0.71      0.69       262
#
#     accuracy                           0.78       749
#    macro avg       0.75      0.76      0.76       749
# weighted avg       0.78      0.78      0.78       749

# %%
metrics.plot_roc_curve(rf, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred1, average=None)
# Out:
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.7613876828064015

# %%
cat = CatBoostClassifier(iterations=2000, eval_metric="AUC")
cat.fit(X_train_res, y_train_res)
# Out:
# Learning rate set to 0.00975
# 0:	total: 47.9ms	remaining: 1m 35s
# 1:	total: 48.9ms	remaining: 48.9s
# 2:	total: 49.9ms	remaining: 33.2s
# 3:	total: 50.8ms	remaining: 25.3s
# 4:	total: 51.7ms	remaining: 20.6s
# 5:	total: 52.7ms	remaining: 17.5s
# 6:	total: 53.6ms	remaining: 15.3s
# 7:	total: 54.6ms	remaining: 13.6s
# 8:	total: 55.4ms	remaining: 12.3s
# 9:	total: 56.4ms	remaining: 11.2s
# 10:	total: 57.4ms	remaining: 10.4s
# 11:	total: 58.3ms	remaining: 9.66s
# 12:	total: 59.2ms	remaining: 9.05s
# 13:	total: 60ms	remaining: 8.51s
# 14:	total: 60.9ms	remaining: 8.06s
# 15:	total: 61.9ms	remaining: 7.67s
# 16:	total: 62.8ms	remaining: 7.33s
# 17:	total: 63.8ms	remaining: 7.02s
# 18:	total: 64.7ms	remaining: 6.75s
# 19:	total: 65.7ms	remaining: 6.51s
# 20:	total: 66.6ms	remaining: 6.28s
# 21:	total: 67.7ms	remaining: 6.08s
# 22:	total: 68.6ms	remaining: 5.89s
# 23:	total: 69.5ms	remaining: 5.72s
# 24:	total: 70.4ms	remaining: 5.56s
# 25:	total: 71.1ms	remaining: 5.4s
# 26:	total: 72.1ms	remaining: 5.27s
# 27:	total: 73.1ms	remaining: 5.15s
# 28:	total: 74.2ms	remaining: 5.04s
# 29:	total: 75.1ms	remaining: 4.93s
# 30:	total: 76.1ms	remaining: 4.83s
# 31:	total: 77.1ms	remaining: 4.74s
# 32:	total: 78ms	remaining: 4.65s
# 33:	total: 78.8ms	remaining: 4.56s
# 34:	total: 79.8ms	remaining: 4.48s
# 35:	total: 80.8ms	remaining: 4.41s
# 36:	total: 81.8ms	remaining: 4.34s
# 37:	total: 82.5ms	remaining: 4.26s
# 38:	total: 84.9ms	remaining: 4.27s
# 39:	total: 86.1ms	remaining: 4.22s
# 40:	total: 86.9ms	remaining: 4.15s
# 41:	total: 87.6ms	remaining: 4.08s
# 42:	total: 88.3ms	remaining: 4.02s
# 43:	total: 89.3ms	remaining: 3.97s
# 44:	total: 90.3ms	remaining: 3.92s
# 45:	total: 91.3ms	remaining: 3.88s
# 46:	total: 92.2ms	remaining: 3.83s
# 47:	total: 93.1ms	remaining: 3.78s
# 48:	total: 94.1ms	remaining: 3.75s
# 49:	total: 95.2ms	remaining: 3.71s
# 50:	total: 96ms	remaining: 3.67s
# 51:	total: 97ms	remaining: 3.63s
# 52:	total: 97.8ms	remaining: 3.59s
# 53:	total: 98.7ms	remaining: 3.56s
# 54:	total: 99.7ms	remaining: 3.52s
# 55:	total: 101ms	remaining: 3.49s
# 56:	total: 102ms	remaining: 3.46s
# 57:	total: 103ms	remaining: 3.43s
# 58:	total: 103ms	remaining: 3.4s
# 59:	total: 104ms	remaining: 3.38s
# 60:	total: 105ms	remaining: 3.35s
# 61:	total: 106ms	remaining: 3.32s
# 62:	total: 107ms	remaining: 3.29s
# 63:	total: 108ms	remaining: 3.27s
# 64:	total: 109ms	remaining: 3.25s
# 65:	total: 110ms	remaining: 3.22s
# 66:	total: 111ms	remaining: 3.2s
# 67:	total: 112ms	remaining: 3.18s
# 68:	total: 113ms	remaining: 3.16s
# 69:	total: 114ms	remaining: 3.14s
# 70:	total: 115ms	remaining: 3.12s
# 71:	total: 116ms	remaining: 3.1s
# 72:	total: 117ms	remaining: 3.08s
# 73:	total: 118ms	remaining: 3.06s
# 74:	total: 118ms	remaining: 3.04s
# 75:	total: 119ms	remaining: 3.02s
# 76:	total: 120ms	remaining: 3.01s
# 77:	total: 121ms	remaining: 2.99s
# 78:	total: 122ms	remaining: 2.97s
# 79:	total: 123ms	remaining: 2.96s
# 80:	total: 124ms	remaining: 2.94s
# 81:	total: 125ms	remaining: 2.92s
# 82:	total: 126ms	remaining: 2.91s
# 83:	total: 127ms	remaining: 2.9s
# 84:	total: 128ms	remaining: 2.88s
# 85:	total: 129ms	remaining: 2.87s
# 86:	total: 130ms	remaining: 2.85s
# 87:	total: 131ms	remaining: 2.84s
# 88:	total: 132ms	remaining: 2.83s
# 89:	total: 133ms	remaining: 2.81s
# 90:	total: 134ms	remaining: 2.8s
# 91:	total: 135ms	remaining: 2.79s
# 92:	total: 135ms	remaining: 2.78s
# 93:	total: 136ms	remaining: 2.76s
# 94:	total: 137ms	remaining: 2.75s
# 95:	total: 138ms	remaining: 2.74s
# 96:	total: 139ms	remaining: 2.73s
# 97:	total: 140ms	remaining: 2.72s
# 98:	total: 141ms	remaining: 2.71s
# 99:	total: 142ms	remaining: 2.7s
# 100:	total: 143ms	remaining: 2.69s
# 101:	total: 144ms	remaining: 2.68s
# 102:	total: 145ms	remaining: 2.67s
# 103:	total: 146ms	remaining: 2.66s
# 104:	total: 147ms	remaining: 2.65s
# 105:	total: 148ms	remaining: 2.64s
# 106:	total: 149ms	remaining: 2.63s
# 107:	total: 150ms	remaining: 2.62s
# 108:	total: 151ms	remaining: 2.61s
# 109:	total: 152ms	remaining: 2.6s
# 110:	total: 153ms	remaining: 2.6s
# 111:	total: 154ms	remaining: 2.59s
# 112:	total: 155ms	remaining: 2.58s
# 113:	total: 155ms	remaining: 2.57s
# 114:	total: 156ms	remaining: 2.56s
# 115:	total: 157ms	remaining: 2.55s
# 116:	total: 158ms	remaining: 2.54s
# 117:	total: 159ms	remaining: 2.54s
# 118:	total: 160ms	remaining: 2.53s
# 119:	total: 161ms	remaining: 2.52s
# 120:	total: 162ms	remaining: 2.51s
# 121:	total: 163ms	remaining: 2.51s
# 122:	total: 164ms	remaining: 2.5s
# 123:	total: 165ms	remaining: 2.49s
# 124:	total: 165ms	remaining: 2.48s
# 125:	total: 166ms	remaining: 2.48s
# 126:	total: 167ms	remaining: 2.47s
# 127:	total: 168ms	remaining: 2.46s
# 128:	total: 169ms	remaining: 2.46s
# 129:	total: 170ms	remaining: 2.45s
# 130:	total: 171ms	remaining: 2.44s
# 131:	total: 172ms	remaining: 2.44s
# 132:	total: 173ms	remaining: 2.43s
# 133:	total: 174ms	remaining: 2.42s
# 134:	total: 175ms	remaining: 2.42s
# 135:	total: 176ms	remaining: 2.41s
# 136:	total: 177ms	remaining: 2.4s
# 137:	total: 178ms	remaining: 2.4s
# 138:	total: 179ms	remaining: 2.39s
# 139:	total: 180ms	remaining: 2.39s
# 140:	total: 181ms	remaining: 2.38s
# 141:	total: 182ms	remaining: 2.38s
# 142:	total: 183ms	remaining: 2.37s
# 143:	total: 184ms	remaining: 2.37s
# 144:	total: 184ms	remaining: 2.36s
# 145:	total: 185ms	remaining: 2.35s
# 146:	total: 186ms	remaining: 2.35s
# 147:	total: 187ms	remaining: 2.34s
# 148:	total: 188ms	remaining: 2.34s
# 149:	total: 189ms	remaining: 2.33s
# 150:	total: 190ms	remaining: 2.33s
# 151:	total: 191ms	remaining: 2.32s
# 152:	total: 192ms	remaining: 2.32s
# 153:	total: 193ms	remaining: 2.31s
# 154:	total: 194ms	remaining: 2.31s
# 155:	total: 195ms	remaining: 2.3s
# 156:	total: 196ms	remaining: 2.3s
# 157:	total: 197ms	remaining: 2.3s
# 158:	total: 198ms	remaining: 2.29s
# 159:	total: 199ms	remaining: 2.29s
# 160:	total: 200ms	remaining: 2.28s
# 161:	total: 201ms	remaining: 2.28s
# 162:	total: 202ms	remaining: 2.27s
# 163:	total: 203ms	remaining: 2.27s
# 164:	total: 204ms	remaining: 2.26s
# 165:	total: 205ms	remaining: 2.26s
# 166:	total: 205ms	remaining: 2.25s
# 167:	total: 206ms	remaining: 2.25s
# 168:	total: 207ms	remaining: 2.25s
# 169:	total: 208ms	remaining: 2.24s
# 170:	total: 209ms	remaining: 2.24s
# 171:	total: 210ms	remaining: 2.23s
# 172:	total: 211ms	remaining: 2.23s
# 173:	total: 212ms	remaining: 2.23s
# 174:	total: 213ms	remaining: 2.22s
# 175:	total: 214ms	remaining: 2.22s
# 176:	total: 215ms	remaining: 2.21s
# 177:	total: 216ms	remaining: 2.21s
# 178:	total: 217ms	remaining: 2.21s
# 179:	total: 218ms	remaining: 2.2s
# 180:	total: 219ms	remaining: 2.2s
# 181:	total: 220ms	remaining: 2.19s
# 182:	total: 221ms	remaining: 2.19s
# 183:	total: 222ms	remaining: 2.19s
# 184:	total: 223ms	remaining: 2.18s
# 185:	total: 224ms	remaining: 2.18s
# 186:	total: 224ms	remaining: 2.18s
# 187:	total: 225ms	remaining: 2.17s
# 188:	total: 226ms	remaining: 2.17s
# 189:	total: 227ms	remaining: 2.16s
# 190:	total: 228ms	remaining: 2.16s
# 191:	total: 229ms	remaining: 2.16s
# 192:	total: 230ms	remaining: 2.15s
# 193:	total: 231ms	remaining: 2.15s
# 194:	total: 232ms	remaining: 2.15s
# 195:	total: 233ms	remaining: 2.14s
# 196:	total: 234ms	remaining: 2.14s
# 197:	total: 235ms	remaining: 2.14s
# 198:	total: 236ms	remaining: 2.13s
# 199:	total: 237ms	remaining: 2.13s
# 200:	total: 238ms	remaining: 2.13s
# 201:	total: 239ms	remaining: 2.12s
# 202:	total: 239ms	remaining: 2.12s
# 203:	total: 240ms	remaining: 2.12s
# 204:	total: 241ms	remaining: 2.11s
# 205:	total: 242ms	remaining: 2.11s
# 206:	total: 243ms	remaining: 2.11s
# 207:	total: 244ms	remaining: 2.1s
# 208:	total: 245ms	remaining: 2.1s
# 209:	total: 246ms	remaining: 2.1s
# 210:	total: 247ms	remaining: 2.1s
# 211:	total: 248ms	remaining: 2.09s
# 212:	total: 249ms	remaining: 2.09s
# 213:	total: 250ms	remaining: 2.08s
# 214:	total: 251ms	remaining: 2.08s
# 215:	total: 252ms	remaining: 2.08s
# 216:	total: 253ms	remaining: 2.08s
# 217:	total: 253ms	remaining: 2.07s
# 218:	total: 254ms	remaining: 2.07s
# 219:	total: 255ms	remaining: 2.07s
# 220:	total: 256ms	remaining: 2.06s
# 221:	total: 257ms	remaining: 2.06s
# 222:	total: 258ms	remaining: 2.06s
# 223:	total: 259ms	remaining: 2.05s
# 224:	total: 260ms	remaining: 2.05s
# 225:	total: 261ms	remaining: 2.05s
# 226:	total: 262ms	remaining: 2.05s
# 227:	total: 263ms	remaining: 2.04s
# 228:	total: 264ms	remaining: 2.04s
# 229:	total: 265ms	remaining: 2.04s
# 230:	total: 266ms	remaining: 2.03s
# 231:	total: 267ms	remaining: 2.03s
# 232:	total: 268ms	remaining: 2.03s
# 233:	total: 269ms	remaining: 2.03s
# 234:	total: 270ms	remaining: 2.02s
# 235:	total: 271ms	remaining: 2.02s
# 236:	total: 271ms	remaining: 2.02s
# 237:	total: 272ms	remaining: 2.02s
# 238:	total: 273ms	remaining: 2.01s
# 239:	total: 274ms	remaining: 2.01s
# 240:	total: 275ms	remaining: 2.01s
# 241:	total: 276ms	remaining: 2.01s
# 242:	total: 277ms	remaining: 2s
# 243:	total: 278ms	remaining: 2s
# 244:	total: 279ms	remaining: 2s
# 245:	total: 280ms	remaining: 2s
# 246:	total: 281ms	remaining: 2s
# 247:	total: 282ms	remaining: 1.99s
# 248:	total: 283ms	remaining: 1.99s
# 249:	total: 284ms	remaining: 1.99s
# 250:	total: 285ms	remaining: 1.99s
# 251:	total: 286ms	remaining: 1.98s
# 252:	total: 287ms	remaining: 1.98s
# 253:	total: 288ms	remaining: 1.98s
# 254:	total: 289ms	remaining: 1.98s
# 255:	total: 290ms	remaining: 1.97s
# 256:	total: 291ms	remaining: 1.97s
# 257:	total: 292ms	remaining: 1.97s
# 258:	total: 292ms	remaining: 1.97s
# 259:	total: 293ms	remaining: 1.96s
# 260:	total: 294ms	remaining: 1.96s
# 261:	total: 295ms	remaining: 1.96s
# 262:	total: 296ms	remaining: 1.96s
# 263:	total: 297ms	remaining: 1.95s
# 264:	total: 298ms	remaining: 1.95s
# 265:	total: 299ms	remaining: 1.95s
# 266:	total: 300ms	remaining: 1.95s
# 267:	total: 301ms	remaining: 1.94s
# 268:	total: 302ms	remaining: 1.94s
# 269:	total: 303ms	remaining: 1.94s
# 270:	total: 304ms	remaining: 1.94s
# 271:	total: 304ms	remaining: 1.93s
# 272:	total: 305ms	remaining: 1.93s
# 273:	total: 306ms	remaining: 1.93s
# 274:	total: 307ms	remaining: 1.92s
# 275:	total: 308ms	remaining: 1.92s
# 276:	total: 309ms	remaining: 1.92s
# 277:	total: 310ms	remaining: 1.92s
# 278:	total: 313ms	remaining: 1.93s
# 279:	total: 315ms	remaining: 1.93s
# 280:	total: 316ms	remaining: 1.93s
# 281:	total: 319ms	remaining: 1.94s
# 282:	total: 320ms	remaining: 1.94s
# 283:	total: 321ms	remaining: 1.94s
# 284:	total: 323ms	remaining: 1.95s
# 285:	total: 325ms	remaining: 1.95s
# 286:	total: 327ms	remaining: 1.95s
# 287:	total: 329ms	remaining: 1.95s
# 288:	total: 330ms	remaining: 1.95s
# 289:	total: 330ms	remaining: 1.95s
# 290:	total: 334ms	remaining: 1.96s
# 291:	total: 336ms	remaining: 1.97s
# 292:	total: 337ms	remaining: 1.96s
# 293:	total: 338ms	remaining: 1.96s
# 294:	total: 341ms	remaining: 1.97s
# 295:	total: 342ms	remaining: 1.97s
# 296:	total: 343ms	remaining: 1.97s
# 297:	total: 344ms	remaining: 1.97s
# 298:	total: 345ms	remaining: 1.96s
# 299:	total: 348ms	remaining: 1.97s
# 300:	total: 351ms	remaining: 1.98s
# 301:	total: 355ms	remaining: 2s
# 302:	total: 356ms	remaining: 2s
# 303:	total: 358ms	remaining: 2s
# 304:	total: 360ms	remaining: 2s
# 305:	total: 361ms	remaining: 2s
# 306:	total: 362ms	remaining: 2s
# 307:	total: 363ms	remaining: 2s
# 308:	total: 364ms	remaining: 1.99s
# 309:	total: 365ms	remaining: 1.99s
# 310:	total: 366ms	remaining: 1.99s
# 311:	total: 367ms	remaining: 1.99s
# 312:	total: 368ms	remaining: 1.98s
# 313:	total: 369ms	remaining: 1.98s
# 314:	total: 370ms	remaining: 1.98s
# 315:	total: 371ms	remaining: 1.98s
# 316:	total: 372ms	remaining: 1.97s
# 317:	total: 373ms	remaining: 1.97s
# 318:	total: 373ms	remaining: 1.97s
# 319:	total: 374ms	remaining: 1.97s
# 320:	total: 375ms	remaining: 1.96s
# 321:	total: 376ms	remaining: 1.96s
# 322:	total: 377ms	remaining: 1.96s
# 323:	total: 378ms	remaining: 1.96s
# 324:	total: 379ms	remaining: 1.95s
# 325:	total: 380ms	remaining: 1.95s
# 326:	total: 381ms	remaining: 1.95s
# 327:	total: 382ms	remaining: 1.95s
# 328:	total: 383ms	remaining: 1.95s
# 329:	total: 384ms	remaining: 1.94s
# 330:	total: 385ms	remaining: 1.94s
# 331:	total: 386ms	remaining: 1.94s
# 332:	total: 387ms	remaining: 1.94s
# 333:	total: 388ms	remaining: 1.94s
# 334:	total: 389ms	remaining: 1.93s
# 335:	total: 390ms	remaining: 1.93s
# 336:	total: 391ms	remaining: 1.93s
# 337:	total: 392ms	remaining: 1.93s
# 338:	total: 393ms	remaining: 1.93s
# 339:	total: 394ms	remaining: 1.93s
# 340:	total: 395ms	remaining: 1.92s
# 341:	total: 396ms	remaining: 1.92s
# 342:	total: 397ms	remaining: 1.92s
# 343:	total: 398ms	remaining: 1.92s
# 344:	total: 399ms	remaining: 1.91s
# 345:	total: 400ms	remaining: 1.91s
# 346:	total: 401ms	remaining: 1.91s
# 347:	total: 402ms	remaining: 1.91s
# 348:	total: 403ms	remaining: 1.91s
# 349:	total: 404ms	remaining: 1.9s
# 350:	total: 405ms	remaining: 1.9s
# 351:	total: 406ms	remaining: 1.9s
# 352:	total: 407ms	remaining: 1.9s
# 353:	total: 408ms	remaining: 1.9s
# 354:	total: 409ms	remaining: 1.89s
# 355:	total: 410ms	remaining: 1.89s
# 356:	total: 411ms	remaining: 1.89s
# 357:	total: 412ms	remaining: 1.89s
# 358:	total: 413ms	remaining: 1.89s
# 359:	total: 414ms	remaining: 1.89s
# 360:	total: 415ms	remaining: 1.88s
# 361:	total: 416ms	remaining: 1.88s
# 362:	total: 417ms	remaining: 1.88s
# 363:	total: 418ms	remaining: 1.88s
# 364:	total: 418ms	remaining: 1.87s
# 365:	total: 419ms	remaining: 1.87s
# 366:	total: 420ms	remaining: 1.87s
# 367:	total: 421ms	remaining: 1.87s
# 368:	total: 422ms	remaining: 1.87s
# 369:	total: 423ms	remaining: 1.86s
# 370:	total: 424ms	remaining: 1.86s
# 371:	total: 425ms	remaining: 1.86s
# 372:	total: 426ms	remaining: 1.86s
# 373:	total: 427ms	remaining: 1.86s
# 374:	total: 428ms	remaining: 1.85s
# 375:	total: 429ms	remaining: 1.85s
# 376:	total: 430ms	remaining: 1.85s
# 377:	total: 431ms	remaining: 1.85s
# 378:	total: 432ms	remaining: 1.85s
# 379:	total: 433ms	remaining: 1.84s
# 380:	total: 434ms	remaining: 1.84s
# 381:	total: 435ms	remaining: 1.84s
# 382:	total: 436ms	remaining: 1.84s
# 383:	total: 436ms	remaining: 1.84s
# 384:	total: 437ms	remaining: 1.83s
# 385:	total: 438ms	remaining: 1.83s
# 386:	total: 439ms	remaining: 1.83s
# 387:	total: 440ms	remaining: 1.83s
# 388:	total: 441ms	remaining: 1.83s
# 389:	total: 442ms	remaining: 1.82s
# 390:	total: 443ms	remaining: 1.82s
# 391:	total: 444ms	remaining: 1.82s
# 392:	total: 445ms	remaining: 1.82s
# 393:	total: 446ms	remaining: 1.82s
# 394:	total: 447ms	remaining: 1.81s
# 395:	total: 448ms	remaining: 1.81s
# 396:	total: 449ms	remaining: 1.81s
# 397:	total: 449ms	remaining: 1.81s
# 398:	total: 450ms	remaining: 1.81s
# 399:	total: 451ms	remaining: 1.8s
# 400:	total: 452ms	remaining: 1.8s
# 401:	total: 453ms	remaining: 1.8s
# 402:	total: 454ms	remaining: 1.8s
# 403:	total: 455ms	remaining: 1.8s
# 404:	total: 456ms	remaining: 1.8s
# 405:	total: 457ms	remaining: 1.79s
# 406:	total: 458ms	remaining: 1.79s
# 407:	total: 459ms	remaining: 1.79s
# 408:	total: 460ms	remaining: 1.79s
# 409:	total: 461ms	remaining: 1.79s
# 410:	total: 462ms	remaining: 1.78s
# 411:	total: 463ms	remaining: 1.78s
# 412:	total: 464ms	remaining: 1.78s
# 413:	total: 465ms	remaining: 1.78s
# 414:	total: 466ms	remaining: 1.78s
# 415:	total: 466ms	remaining: 1.78s
# 416:	total: 467ms	remaining: 1.77s
# 417:	total: 468ms	remaining: 1.77s
# 418:	total: 469ms	remaining: 1.77s
# 419:	total: 470ms	remaining: 1.77s
# 420:	total: 471ms	remaining: 1.77s
# 421:	total: 472ms	remaining: 1.76s
# 422:	total: 473ms	remaining: 1.76s
# 423:	total: 474ms	remaining: 1.76s
# 424:	total: 475ms	remaining: 1.76s
# 425:	total: 476ms	remaining: 1.76s
# 426:	total: 477ms	remaining: 1.76s
# 427:	total: 478ms	remaining: 1.75s
# 428:	total: 479ms	remaining: 1.75s
# 429:	total: 480ms	remaining: 1.75s
# 430:	total: 481ms	remaining: 1.75s
# 431:	total: 482ms	remaining: 1.75s
# 432:	total: 483ms	remaining: 1.75s
# 433:	total: 484ms	remaining: 1.75s
# 434:	total: 485ms	remaining: 1.74s
# 435:	total: 486ms	remaining: 1.74s
# 436:	total: 487ms	remaining: 1.74s
# 437:	total: 488ms	remaining: 1.74s
# 438:	total: 489ms	remaining: 1.74s
# 439:	total: 490ms	remaining: 1.74s
# 440:	total: 491ms	remaining: 1.73s
# 441:	total: 491ms	remaining: 1.73s
# 442:	total: 492ms	remaining: 1.73s
# 443:	total: 493ms	remaining: 1.73s
# 444:	total: 494ms	remaining: 1.73s
# 445:	total: 495ms	remaining: 1.73s
# 446:	total: 496ms	remaining: 1.72s
# 447:	total: 497ms	remaining: 1.72s
# 448:	total: 498ms	remaining: 1.72s
# 449:	total: 499ms	remaining: 1.72s
# 450:	total: 500ms	remaining: 1.72s
# 451:	total: 501ms	remaining: 1.72s
# 452:	total: 502ms	remaining: 1.71s
# 453:	total: 503ms	remaining: 1.71s
# 454:	total: 504ms	remaining: 1.71s
# 455:	total: 505ms	remaining: 1.71s
# 456:	total: 506ms	remaining: 1.71s
# 457:	total: 507ms	remaining: 1.71s
# 458:	total: 507ms	remaining: 1.7s
# 459:	total: 508ms	remaining: 1.7s
# 460:	total: 509ms	remaining: 1.7s
# 461:	total: 510ms	remaining: 1.7s
# 462:	total: 511ms	remaining: 1.7s
# 463:	total: 512ms	remaining: 1.7s
# 464:	total: 513ms	remaining: 1.69s
# 465:	total: 514ms	remaining: 1.69s
# 466:	total: 515ms	remaining: 1.69s
# 467:	total: 516ms	remaining: 1.69s
# 468:	total: 517ms	remaining: 1.69s
# 469:	total: 518ms	remaining: 1.69s
# 470:	total: 519ms	remaining: 1.68s
# 471:	total: 520ms	remaining: 1.68s
# 472:	total: 520ms	remaining: 1.68s
# 473:	total: 521ms	remaining: 1.68s
# 474:	total: 522ms	remaining: 1.68s
# 475:	total: 523ms	remaining: 1.68s
# 476:	total: 524ms	remaining: 1.67s
# 477:	total: 525ms	remaining: 1.67s
# 478:	total: 526ms	remaining: 1.67s
# 479:	total: 527ms	remaining: 1.67s
# 480:	total: 528ms	remaining: 1.67s
# 481:	total: 529ms	remaining: 1.67s
# 482:	total: 530ms	remaining: 1.66s
# 483:	total: 531ms	remaining: 1.66s
# 484:	total: 532ms	remaining: 1.66s
# 485:	total: 533ms	remaining: 1.66s
# 486:	total: 534ms	remaining: 1.66s
# 487:	total: 535ms	remaining: 1.66s
# 488:	total: 536ms	remaining: 1.66s
# 489:	total: 537ms	remaining: 1.66s
# 490:	total: 538ms	remaining: 1.65s
# 491:	total: 539ms	remaining: 1.65s
# 492:	total: 540ms	remaining: 1.65s
# 493:	total: 541ms	remaining: 1.65s
# 494:	total: 542ms	remaining: 1.65s
# 495:	total: 543ms	remaining: 1.65s
# 496:	total: 544ms	remaining: 1.64s
# 497:	total: 544ms	remaining: 1.64s
# 498:	total: 546ms	remaining: 1.64s
# 499:	total: 546ms	remaining: 1.64s
# 500:	total: 547ms	remaining: 1.64s
# 501:	total: 548ms	remaining: 1.64s
# 502:	total: 549ms	remaining: 1.63s
# 503:	total: 550ms	remaining: 1.63s
# 504:	total: 551ms	remaining: 1.63s
# 505:	total: 552ms	remaining: 1.63s
# 506:	total: 553ms	remaining: 1.63s
# 507:	total: 554ms	remaining: 1.63s
# 508:	total: 555ms	remaining: 1.63s
# 509:	total: 556ms	remaining: 1.62s
# 510:	total: 557ms	remaining: 1.62s
# 511:	total: 558ms	remaining: 1.62s
# 512:	total: 559ms	remaining: 1.62s
# 513:	total: 560ms	remaining: 1.62s
# 514:	total: 561ms	remaining: 1.62s
# 515:	total: 562ms	remaining: 1.61s
# 516:	total: 562ms	remaining: 1.61s
# 517:	total: 563ms	remaining: 1.61s
# 518:	total: 564ms	remaining: 1.61s
# 519:	total: 565ms	remaining: 1.61s
# 520:	total: 566ms	remaining: 1.61s
# 521:	total: 567ms	remaining: 1.6s
# 522:	total: 568ms	remaining: 1.6s
# 523:	total: 569ms	remaining: 1.6s
# 524:	total: 570ms	remaining: 1.6s
# 525:	total: 571ms	remaining: 1.6s
# 526:	total: 572ms	remaining: 1.6s
# 527:	total: 573ms	remaining: 1.6s
# 528:	total: 574ms	remaining: 1.59s
# 529:	total: 575ms	remaining: 1.59s
# 530:	total: 575ms	remaining: 1.59s
# 531:	total: 576ms	remaining: 1.59s
# 532:	total: 577ms	remaining: 1.59s
# 533:	total: 578ms	remaining: 1.59s
# 534:	total: 579ms	remaining: 1.59s
# 535:	total: 580ms	remaining: 1.58s
# 536:	total: 581ms	remaining: 1.58s
# 537:	total: 582ms	remaining: 1.58s
# 538:	total: 583ms	remaining: 1.58s
# 539:	total: 584ms	remaining: 1.58s
# 540:	total: 585ms	remaining: 1.58s
# 541:	total: 586ms	remaining: 1.58s
# 542:	total: 587ms	remaining: 1.58s
# 543:	total: 588ms	remaining: 1.57s
# 544:	total: 589ms	remaining: 1.57s
# 545:	total: 590ms	remaining: 1.57s
# 546:	total: 591ms	remaining: 1.57s
# 547:	total: 592ms	remaining: 1.57s
# 548:	total: 593ms	remaining: 1.57s
# 549:	total: 594ms	remaining: 1.56s
# 550:	total: 595ms	remaining: 1.56s
# 551:	total: 596ms	remaining: 1.56s
# 552:	total: 597ms	remaining: 1.56s
# 553:	total: 598ms	remaining: 1.56s
# 554:	total: 599ms	remaining: 1.56s
# 555:	total: 600ms	remaining: 1.56s
# 556:	total: 601ms	remaining: 1.56s
# 557:	total: 602ms	remaining: 1.55s
# 558:	total: 603ms	remaining: 1.55s
# 559:	total: 604ms	remaining: 1.55s
# 560:	total: 604ms	remaining: 1.55s
# 561:	total: 605ms	remaining: 1.55s
# 562:	total: 606ms	remaining: 1.55s
# 563:	total: 607ms	remaining: 1.55s
# 564:	total: 608ms	remaining: 1.54s
# 565:	total: 609ms	remaining: 1.54s
# 566:	total: 610ms	remaining: 1.54s
# 567:	total: 611ms	remaining: 1.54s
# 568:	total: 612ms	remaining: 1.54s
# 569:	total: 613ms	remaining: 1.54s
# 570:	total: 614ms	remaining: 1.53s
# 571:	total: 615ms	remaining: 1.53s
# 572:	total: 616ms	remaining: 1.53s
# 573:	total: 617ms	remaining: 1.53s
# 574:	total: 617ms	remaining: 1.53s
# 575:	total: 618ms	remaining: 1.53s
# 576:	total: 619ms	remaining: 1.53s
# 577:	total: 620ms	remaining: 1.52s
# 578:	total: 621ms	remaining: 1.52s
# 579:	total: 622ms	remaining: 1.52s
# 580:	total: 623ms	remaining: 1.52s
# 581:	total: 624ms	remaining: 1.52s
# 582:	total: 625ms	remaining: 1.52s
# 583:	total: 626ms	remaining: 1.52s
# 584:	total: 627ms	remaining: 1.51s
# 585:	total: 628ms	remaining: 1.51s
# 586:	total: 629ms	remaining: 1.51s
# 587:	total: 629ms	remaining: 1.51s
# 588:	total: 630ms	remaining: 1.51s
# 589:	total: 631ms	remaining: 1.51s
# 590:	total: 632ms	remaining: 1.51s
# 591:	total: 633ms	remaining: 1.5s
# 592:	total: 634ms	remaining: 1.5s
# 593:	total: 635ms	remaining: 1.5s
# 594:	total: 636ms	remaining: 1.5s
# 595:	total: 637ms	remaining: 1.5s
# 596:	total: 638ms	remaining: 1.5s
# 597:	total: 639ms	remaining: 1.5s
# 598:	total: 640ms	remaining: 1.5s
# 599:	total: 641ms	remaining: 1.49s
# 600:	total: 641ms	remaining: 1.49s
# 601:	total: 642ms	remaining: 1.49s
# 602:	total: 643ms	remaining: 1.49s
# 603:	total: 644ms	remaining: 1.49s
# 604:	total: 645ms	remaining: 1.49s
# 605:	total: 646ms	remaining: 1.49s
# 606:	total: 647ms	remaining: 1.48s
# 607:	total: 648ms	remaining: 1.48s
# 608:	total: 649ms	remaining: 1.48s
# 609:	total: 650ms	remaining: 1.48s
# 610:	total: 651ms	remaining: 1.48s
# 611:	total: 652ms	remaining: 1.48s
# 612:	total: 653ms	remaining: 1.48s
# 613:	total: 654ms	remaining: 1.48s
# 614:	total: 655ms	remaining: 1.47s
# 615:	total: 656ms	remaining: 1.47s
# 616:	total: 656ms	remaining: 1.47s
# 617:	total: 657ms	remaining: 1.47s
# 618:	total: 658ms	remaining: 1.47s
# 619:	total: 659ms	remaining: 1.47s
# 620:	total: 660ms	remaining: 1.47s
# 621:	total: 661ms	remaining: 1.46s
# 622:	total: 662ms	remaining: 1.46s
# 623:	total: 663ms	remaining: 1.46s
# 624:	total: 664ms	remaining: 1.46s
# 625:	total: 665ms	remaining: 1.46s
# 626:	total: 666ms	remaining: 1.46s
# 627:	total: 667ms	remaining: 1.46s
# 628:	total: 668ms	remaining: 1.46s
# 629:	total: 669ms	remaining: 1.45s
# 630:	total: 670ms	remaining: 1.45s
# 631:	total: 671ms	remaining: 1.45s
# 632:	total: 672ms	remaining: 1.45s
# 633:	total: 673ms	remaining: 1.45s
# 634:	total: 674ms	remaining: 1.45s
# 635:	total: 675ms	remaining: 1.45s
# 636:	total: 676ms	remaining: 1.45s
# 637:	total: 677ms	remaining: 1.44s
# 638:	total: 678ms	remaining: 1.44s
# 639:	total: 679ms	remaining: 1.44s
# 640:	total: 679ms	remaining: 1.44s
# 641:	total: 680ms	remaining: 1.44s
# 642:	total: 681ms	remaining: 1.44s
# 643:	total: 682ms	remaining: 1.44s
# 644:	total: 683ms	remaining: 1.44s
# 645:	total: 684ms	remaining: 1.43s
# 646:	total: 685ms	remaining: 1.43s
# 647:	total: 686ms	remaining: 1.43s
# 648:	total: 687ms	remaining: 1.43s
# 649:	total: 688ms	remaining: 1.43s
# 650:	total: 689ms	remaining: 1.43s
# 651:	total: 690ms	remaining: 1.43s
# 652:	total: 691ms	remaining: 1.43s
# 653:	total: 692ms	remaining: 1.42s
# 654:	total: 693ms	remaining: 1.42s
# 655:	total: 694ms	remaining: 1.42s
# 656:	total: 695ms	remaining: 1.42s
# 657:	total: 696ms	remaining: 1.42s
# 658:	total: 696ms	remaining: 1.42s
# 659:	total: 697ms	remaining: 1.42s
# 660:	total: 698ms	remaining: 1.41s
# 661:	total: 699ms	remaining: 1.41s
# 662:	total: 700ms	remaining: 1.41s
# 663:	total: 701ms	remaining: 1.41s
# 664:	total: 702ms	remaining: 1.41s
# 665:	total: 703ms	remaining: 1.41s
# 666:	total: 704ms	remaining: 1.41s
# 667:	total: 705ms	remaining: 1.41s
# 668:	total: 706ms	remaining: 1.4s
# 669:	total: 707ms	remaining: 1.4s
# 670:	total: 708ms	remaining: 1.4s
# 671:	total: 709ms	remaining: 1.4s
# 672:	total: 710ms	remaining: 1.4s
# 673:	total: 711ms	remaining: 1.4s
# 674:	total: 712ms	remaining: 1.4s
# 675:	total: 713ms	remaining: 1.4s
# 676:	total: 714ms	remaining: 1.39s
# 677:	total: 715ms	remaining: 1.39s
# 678:	total: 715ms	remaining: 1.39s
# 679:	total: 716ms	remaining: 1.39s
# 680:	total: 717ms	remaining: 1.39s
# 681:	total: 718ms	remaining: 1.39s
# 682:	total: 719ms	remaining: 1.39s
# 683:	total: 720ms	remaining: 1.39s
# 684:	total: 721ms	remaining: 1.38s
# 685:	total: 722ms	remaining: 1.38s
# 686:	total: 723ms	remaining: 1.38s
# 687:	total: 724ms	remaining: 1.38s
# 688:	total: 725ms	remaining: 1.38s
# 689:	total: 726ms	remaining: 1.38s
# 690:	total: 727ms	remaining: 1.38s
# 691:	total: 728ms	remaining: 1.38s
# 692:	total: 729ms	remaining: 1.37s
# 693:	total: 730ms	remaining: 1.37s
# 694:	total: 731ms	remaining: 1.37s
# 695:	total: 732ms	remaining: 1.37s
# 696:	total: 733ms	remaining: 1.37s
# 697:	total: 734ms	remaining: 1.37s
# 698:	total: 735ms	remaining: 1.37s
# 699:	total: 736ms	remaining: 1.37s
# 700:	total: 737ms	remaining: 1.36s
# 701:	total: 738ms	remaining: 1.36s
# 702:	total: 739ms	remaining: 1.36s
# 703:	total: 740ms	remaining: 1.36s
# 704:	total: 741ms	remaining: 1.36s
# 705:	total: 742ms	remaining: 1.36s
# 706:	total: 743ms	remaining: 1.36s
# 707:	total: 744ms	remaining: 1.36s
# 708:	total: 744ms	remaining: 1.35s
# 709:	total: 745ms	remaining: 1.35s
# 710:	total: 746ms	remaining: 1.35s
# 711:	total: 747ms	remaining: 1.35s
# 712:	total: 748ms	remaining: 1.35s
# 713:	total: 749ms	remaining: 1.35s
# 714:	total: 750ms	remaining: 1.35s
# 715:	total: 751ms	remaining: 1.35s
# 716:	total: 752ms	remaining: 1.35s
# 717:	total: 753ms	remaining: 1.34s
# 718:	total: 754ms	remaining: 1.34s
# 719:	total: 755ms	remaining: 1.34s
# 720:	total: 756ms	remaining: 1.34s
# 721:	total: 757ms	remaining: 1.34s
# 722:	total: 758ms	remaining: 1.34s
# 723:	total: 759ms	remaining: 1.34s
# 724:	total: 760ms	remaining: 1.34s
# 725:	total: 761ms	remaining: 1.33s
# 726:	total: 762ms	remaining: 1.33s
# 727:	total: 763ms	remaining: 1.33s
# 728:	total: 764ms	remaining: 1.33s
# 729:	total: 765ms	remaining: 1.33s
# 730:	total: 766ms	remaining: 1.33s
# 731:	total: 767ms	remaining: 1.33s
# 732:	total: 767ms	remaining: 1.33s
# 733:	total: 768ms	remaining: 1.32s
# 734:	total: 769ms	remaining: 1.32s
# 735:	total: 770ms	remaining: 1.32s
# 736:	total: 771ms	remaining: 1.32s
# 737:	total: 772ms	remaining: 1.32s
# 738:	total: 773ms	remaining: 1.32s
# 739:	total: 774ms	remaining: 1.32s
# 740:	total: 775ms	remaining: 1.32s
# 741:	total: 776ms	remaining: 1.32s
# 742:	total: 778ms	remaining: 1.31s
# 743:	total: 779ms	remaining: 1.31s
# 744:	total: 780ms	remaining: 1.31s
# 745:	total: 781ms	remaining: 1.31s
# 746:	total: 782ms	remaining: 1.31s
# 747:	total: 783ms	remaining: 1.31s
# 748:	total: 784ms	remaining: 1.31s
# 749:	total: 785ms	remaining: 1.31s
# 750:	total: 786ms	remaining: 1.31s
# 751:	total: 787ms	remaining: 1.3s
# 752:	total: 788ms	remaining: 1.3s
# 753:	total: 789ms	remaining: 1.3s
# 754:	total: 790ms	remaining: 1.3s
# 755:	total: 791ms	remaining: 1.3s
# 756:	total: 791ms	remaining: 1.3s
# 757:	total: 792ms	remaining: 1.3s
# 758:	total: 793ms	remaining: 1.3s
# 759:	total: 794ms	remaining: 1.3s
# 760:	total: 795ms	remaining: 1.29s
# 761:	total: 797ms	remaining: 1.29s
# 762:	total: 797ms	remaining: 1.29s
# 763:	total: 798ms	remaining: 1.29s
# 764:	total: 799ms	remaining: 1.29s
# 765:	total: 800ms	remaining: 1.29s
# 766:	total: 801ms	remaining: 1.29s
# 767:	total: 802ms	remaining: 1.29s
# 768:	total: 803ms	remaining: 1.28s
# 769:	total: 804ms	remaining: 1.28s
# 770:	total: 805ms	remaining: 1.28s
# 771:	total: 806ms	remaining: 1.28s
# 772:	total: 807ms	remaining: 1.28s
# 773:	total: 808ms	remaining: 1.28s
# 774:	total: 809ms	remaining: 1.28s
# 775:	total: 810ms	remaining: 1.28s
# 776:	total: 811ms	remaining: 1.27s
# 777:	total: 811ms	remaining: 1.27s
# 778:	total: 812ms	remaining: 1.27s
# 779:	total: 813ms	remaining: 1.27s
# 780:	total: 814ms	remaining: 1.27s
# 781:	total: 815ms	remaining: 1.27s
# 782:	total: 816ms	remaining: 1.27s
# 783:	total: 817ms	remaining: 1.27s
# 784:	total: 818ms	remaining: 1.27s
# 785:	total: 819ms	remaining: 1.26s
# 786:	total: 820ms	remaining: 1.26s
# 787:	total: 821ms	remaining: 1.26s
# 788:	total: 822ms	remaining: 1.26s
# 789:	total: 823ms	remaining: 1.26s
# 790:	total: 824ms	remaining: 1.26s
# 791:	total: 825ms	remaining: 1.26s
# 792:	total: 825ms	remaining: 1.26s
# 793:	total: 826ms	remaining: 1.25s
# 794:	total: 827ms	remaining: 1.25s
# 795:	total: 828ms	remaining: 1.25s
# 796:	total: 829ms	remaining: 1.25s
# 797:	total: 830ms	remaining: 1.25s
# 798:	total: 831ms	remaining: 1.25s
# 799:	total: 832ms	remaining: 1.25s
# 800:	total: 833ms	remaining: 1.25s
# 801:	total: 834ms	remaining: 1.25s
# 802:	total: 835ms	remaining: 1.24s
# 803:	total: 836ms	remaining: 1.24s
# 804:	total: 837ms	remaining: 1.24s
# 805:	total: 838ms	remaining: 1.24s
# 806:	total: 839ms	remaining: 1.24s
# 807:	total: 840ms	remaining: 1.24s
# 808:	total: 841ms	remaining: 1.24s
# 809:	total: 842ms	remaining: 1.24s
# 810:	total: 843ms	remaining: 1.24s
# 811:	total: 844ms	remaining: 1.23s
# 812:	total: 845ms	remaining: 1.23s
# 813:	total: 846ms	remaining: 1.23s
# 814:	total: 847ms	remaining: 1.23s
# 815:	total: 848ms	remaining: 1.23s
# 816:	total: 849ms	remaining: 1.23s
# 817:	total: 850ms	remaining: 1.23s
# 818:	total: 851ms	remaining: 1.23s
# 819:	total: 852ms	remaining: 1.23s
# 820:	total: 852ms	remaining: 1.22s
# 821:	total: 853ms	remaining: 1.22s
# 822:	total: 854ms	remaining: 1.22s
# 823:	total: 855ms	remaining: 1.22s
# 824:	total: 856ms	remaining: 1.22s
# 825:	total: 857ms	remaining: 1.22s
# 826:	total: 859ms	remaining: 1.22s
# 827:	total: 860ms	remaining: 1.22s
# 828:	total: 861ms	remaining: 1.22s
# 829:	total: 862ms	remaining: 1.21s
# 830:	total: 863ms	remaining: 1.21s
# 831:	total: 863ms	remaining: 1.21s
# 832:	total: 864ms	remaining: 1.21s
# 833:	total: 865ms	remaining: 1.21s
# 834:	total: 866ms	remaining: 1.21s
# 835:	total: 867ms	remaining: 1.21s
# 836:	total: 868ms	remaining: 1.21s
# 837:	total: 869ms	remaining: 1.21s
# 838:	total: 870ms	remaining: 1.2s
# 839:	total: 871ms	remaining: 1.2s
# 840:	total: 872ms	remaining: 1.2s
# 841:	total: 873ms	remaining: 1.2s
# 842:	total: 874ms	remaining: 1.2s
# 843:	total: 875ms	remaining: 1.2s
# 844:	total: 876ms	remaining: 1.2s
# 845:	total: 877ms	remaining: 1.2s
# 846:	total: 878ms	remaining: 1.2s
# 847:	total: 879ms	remaining: 1.19s
# 848:	total: 880ms	remaining: 1.19s
# 849:	total: 881ms	remaining: 1.19s
# 850:	total: 882ms	remaining: 1.19s
# 851:	total: 883ms	remaining: 1.19s
# 852:	total: 884ms	remaining: 1.19s
# 853:	total: 885ms	remaining: 1.19s
# 854:	total: 886ms	remaining: 1.19s
# 855:	total: 887ms	remaining: 1.18s
# 856:	total: 888ms	remaining: 1.18s
# 857:	total: 889ms	remaining: 1.18s
# 858:	total: 889ms	remaining: 1.18s
# 859:	total: 890ms	remaining: 1.18s
# 860:	total: 891ms	remaining: 1.18s
# 861:	total: 892ms	remaining: 1.18s
# 862:	total: 893ms	remaining: 1.18s
# 863:	total: 894ms	remaining: 1.18s
# 864:	total: 895ms	remaining: 1.17s
# 865:	total: 896ms	remaining: 1.17s
# 866:	total: 897ms	remaining: 1.17s
# 867:	total: 898ms	remaining: 1.17s
# 868:	total: 899ms	remaining: 1.17s
# 869:	total: 900ms	remaining: 1.17s
# 870:	total: 901ms	remaining: 1.17s
# 871:	total: 902ms	remaining: 1.17s
# 872:	total: 903ms	remaining: 1.17s
# 873:	total: 903ms	remaining: 1.16s
# 874:	total: 904ms	remaining: 1.16s
# 875:	total: 905ms	remaining: 1.16s
# 876:	total: 906ms	remaining: 1.16s
# 877:	total: 907ms	remaining: 1.16s
# 878:	total: 908ms	remaining: 1.16s
# 879:	total: 909ms	remaining: 1.16s
# 880:	total: 910ms	remaining: 1.16s
# 881:	total: 911ms	remaining: 1.16s
# 882:	total: 912ms	remaining: 1.15s
# 883:	total: 913ms	remaining: 1.15s
# 884:	total: 914ms	remaining: 1.15s
# 885:	total: 915ms	remaining: 1.15s
# 886:	total: 916ms	remaining: 1.15s
# 887:	total: 917ms	remaining: 1.15s
# 888:	total: 918ms	remaining: 1.15s
# 889:	total: 919ms	remaining: 1.15s
# 890:	total: 920ms	remaining: 1.15s
# 891:	total: 921ms	remaining: 1.14s
# 892:	total: 922ms	remaining: 1.14s
# 893:	total: 923ms	remaining: 1.14s
# 894:	total: 924ms	remaining: 1.14s
# 895:	total: 925ms	remaining: 1.14s
# 896:	total: 926ms	remaining: 1.14s
# 897:	total: 927ms	remaining: 1.14s
# 898:	total: 928ms	remaining: 1.14s
# 899:	total: 929ms	remaining: 1.14s
# 900:	total: 930ms	remaining: 1.13s
# 901:	total: 931ms	remaining: 1.13s
# 902:	total: 932ms	remaining: 1.13s
# 903:	total: 933ms	remaining: 1.13s
# 904:	total: 934ms	remaining: 1.13s
# 905:	total: 935ms	remaining: 1.13s
# 906:	total: 936ms	remaining: 1.13s
# 907:	total: 937ms	remaining: 1.13s
# 908:	total: 938ms	remaining: 1.13s
# 909:	total: 939ms	remaining: 1.12s
# 910:	total: 940ms	remaining: 1.12s
# 911:	total: 941ms	remaining: 1.12s
# 912:	total: 942ms	remaining: 1.12s
# 913:	total: 943ms	remaining: 1.12s
# 914:	total: 944ms	remaining: 1.12s
# 915:	total: 945ms	remaining: 1.12s
# 916:	total: 946ms	remaining: 1.12s
# 917:	total: 947ms	remaining: 1.12s
# 918:	total: 948ms	remaining: 1.11s
# 919:	total: 949ms	remaining: 1.11s
# 920:	total: 950ms	remaining: 1.11s
# 921:	total: 951ms	remaining: 1.11s
# 922:	total: 952ms	remaining: 1.11s
# 923:	total: 953ms	remaining: 1.11s
# 924:	total: 954ms	remaining: 1.11s
# 925:	total: 955ms	remaining: 1.11s
# 926:	total: 956ms	remaining: 1.11s
# 927:	total: 957ms	remaining: 1.1s
# 928:	total: 958ms	remaining: 1.1s
# 929:	total: 959ms	remaining: 1.1s
# 930:	total: 960ms	remaining: 1.1s
# 931:	total: 961ms	remaining: 1.1s
# 932:	total: 962ms	remaining: 1.1s
# 933:	total: 963ms	remaining: 1.1s
# 934:	total: 964ms	remaining: 1.1s
# 935:	total: 965ms	remaining: 1.1s
# 936:	total: 966ms	remaining: 1.09s
# 937:	total: 967ms	remaining: 1.09s
# 938:	total: 968ms	remaining: 1.09s
# 939:	total: 969ms	remaining: 1.09s
# 940:	total: 970ms	remaining: 1.09s
# 941:	total: 971ms	remaining: 1.09s
# 942:	total: 972ms	remaining: 1.09s
# 943:	total: 973ms	remaining: 1.09s
# 944:	total: 974ms	remaining: 1.09s
# 945:	total: 975ms	remaining: 1.09s
# 946:	total: 976ms	remaining: 1.08s
# 947:	total: 977ms	remaining: 1.08s
# 948:	total: 978ms	remaining: 1.08s
# 949:	total: 979ms	remaining: 1.08s
# 950:	total: 980ms	remaining: 1.08s
# 951:	total: 981ms	remaining: 1.08s
# 952:	total: 982ms	remaining: 1.08s
# 953:	total: 983ms	remaining: 1.08s
# 954:	total: 984ms	remaining: 1.08s
# 955:	total: 985ms	remaining: 1.07s
# 956:	total: 986ms	remaining: 1.07s
# 957:	total: 987ms	remaining: 1.07s
# 958:	total: 988ms	remaining: 1.07s
# 959:	total: 989ms	remaining: 1.07s
# 960:	total: 990ms	remaining: 1.07s
# 961:	total: 991ms	remaining: 1.07s
# 962:	total: 992ms	remaining: 1.07s
# 963:	total: 993ms	remaining: 1.07s
# 964:	total: 994ms	remaining: 1.06s
# 965:	total: 995ms	remaining: 1.06s
# 966:	total: 996ms	remaining: 1.06s
# 967:	total: 997ms	remaining: 1.06s
# 968:	total: 998ms	remaining: 1.06s
# 969:	total: 999ms	remaining: 1.06s
# 970:	total: 999ms	remaining: 1.06s
# 971:	total: 1s	remaining: 1.06s
# 972:	total: 1s	remaining: 1.06s
# 973:	total: 1s	remaining: 1.05s
# 974:	total: 1s	remaining: 1.05s
# 975:	total: 1s	remaining: 1.05s
# 976:	total: 1s	remaining: 1.05s
# 977:	total: 1.01s	remaining: 1.05s
# 978:	total: 1.01s	remaining: 1.05s
# 979:	total: 1.01s	remaining: 1.05s
# 980:	total: 1.01s	remaining: 1.05s
# 981:	total: 1.01s	remaining: 1.05s
# 982:	total: 1.01s	remaining: 1.05s
# 983:	total: 1.01s	remaining: 1.04s
# 984:	total: 1.01s	remaining: 1.04s
# 985:	total: 1.01s	remaining: 1.04s
# 986:	total: 1.01s	remaining: 1.04s
# 987:	total: 1.02s	remaining: 1.04s
# 988:	total: 1.02s	remaining: 1.04s
# 989:	total: 1.02s	remaining: 1.04s
# 990:	total: 1.02s	remaining: 1.04s
# 991:	total: 1.02s	remaining: 1.04s
# 992:	total: 1.02s	remaining: 1.03s
# 993:	total: 1.02s	remaining: 1.03s
# 994:	total: 1.02s	remaining: 1.03s
# 995:	total: 1.02s	remaining: 1.03s
# 996:	total: 1.02s	remaining: 1.03s
# 997:	total: 1.02s	remaining: 1.03s
# 998:	total: 1.03s	remaining: 1.03s
# 999:	total: 1.03s	remaining: 1.03s
# 1000:	total: 1.03s	remaining: 1.03s
# 1001:	total: 1.03s	remaining: 1.02s
# 1002:	total: 1.03s	remaining: 1.02s
# 1003:	total: 1.03s	remaining: 1.02s
# 1004:	total: 1.03s	remaining: 1.02s
# 1005:	total: 1.03s	remaining: 1.02s
# 1006:	total: 1.03s	remaining: 1.02s
# 1007:	total: 1.03s	remaining: 1.02s
# 1008:	total: 1.04s	remaining: 1.02s
# 1009:	total: 1.04s	remaining: 1.02s
# 1010:	total: 1.04s	remaining: 1.02s
# 1011:	total: 1.04s	remaining: 1.01s
# 1012:	total: 1.04s	remaining: 1.01s
# 1013:	total: 1.04s	remaining: 1.01s
# 1014:	total: 1.04s	remaining: 1.01s
# 1015:	total: 1.04s	remaining: 1.01s
# 1016:	total: 1.04s	remaining: 1.01s
# 1017:	total: 1.04s	remaining: 1.01s
# 1018:	total: 1.05s	remaining: 1.01s
# 1019:	total: 1.05s	remaining: 1.01s
# 1020:	total: 1.05s	remaining: 1s
# 1021:	total: 1.05s	remaining: 1s
# 1022:	total: 1.05s	remaining: 1s
# 1023:	total: 1.05s	remaining: 1s
# 1024:	total: 1.05s	remaining: 1s
# 1025:	total: 1.05s	remaining: 1s
# 1026:	total: 1.05s	remaining: 1000ms
# 1027:	total: 1.06s	remaining: 999ms
# 1028:	total: 1.06s	remaining: 998ms
# 1029:	total: 1.06s	remaining: 997ms
# 1030:	total: 1.06s	remaining: 996ms
# 1031:	total: 1.06s	remaining: 994ms
# 1032:	total: 1.06s	remaining: 993ms
# 1033:	total: 1.06s	remaining: 992ms
# 1034:	total: 1.06s	remaining: 991ms
# 1035:	total: 1.06s	remaining: 990ms
# 1036:	total: 1.06s	remaining: 989ms
# 1037:	total: 1.06s	remaining: 988ms
# 1038:	total: 1.07s	remaining: 987ms
# 1039:	total: 1.07s	remaining: 986ms
# 1040:	total: 1.07s	remaining: 985ms
# 1041:	total: 1.07s	remaining: 984ms
# 1042:	total: 1.07s	remaining: 983ms
# 1043:	total: 1.07s	remaining: 981ms
# 1044:	total: 1.07s	remaining: 980ms
# 1045:	total: 1.07s	remaining: 979ms
# 1046:	total: 1.07s	remaining: 978ms
# 1047:	total: 1.07s	remaining: 977ms
# 1048:	total: 1.08s	remaining: 976ms
# 1049:	total: 1.08s	remaining: 975ms
# 1050:	total: 1.08s	remaining: 974ms
# 1051:	total: 1.08s	remaining: 973ms
# 1052:	total: 1.08s	remaining: 972ms
# 1053:	total: 1.08s	remaining: 971ms
# 1054:	total: 1.08s	remaining: 970ms
# 1055:	total: 1.08s	remaining: 970ms
# 1056:	total: 1.08s	remaining: 969ms
# 1057:	total: 1.09s	remaining: 968ms
# 1058:	total: 1.09s	remaining: 967ms
# 1059:	total: 1.09s	remaining: 966ms
# 1060:	total: 1.09s	remaining: 965ms
# 1061:	total: 1.09s	remaining: 964ms
# 1062:	total: 1.09s	remaining: 964ms
# 1063:	total: 1.09s	remaining: 963ms
# 1064:	total: 1.1s	remaining: 962ms
# 1065:	total: 1.1s	remaining: 962ms
# 1066:	total: 1.1s	remaining: 961ms
# 1067:	total: 1.1s	remaining: 960ms
# 1068:	total: 1.1s	remaining: 959ms
# 1069:	total: 1.1s	remaining: 958ms
# 1070:	total: 1.1s	remaining: 957ms
# 1071:	total: 1.1s	remaining: 956ms
# 1072:	total: 1.1s	remaining: 955ms
# 1073:	total: 1.11s	remaining: 955ms
# 1074:	total: 1.11s	remaining: 955ms
# 1075:	total: 1.11s	remaining: 955ms
# 1076:	total: 1.11s	remaining: 954ms
# 1077:	total: 1.11s	remaining: 953ms
# 1078:	total: 1.11s	remaining: 952ms
# 1079:	total: 1.12s	remaining: 952ms
# 1080:	total: 1.12s	remaining: 951ms
# 1081:	total: 1.12s	remaining: 950ms
# 1082:	total: 1.12s	remaining: 949ms
# 1083:	total: 1.12s	remaining: 948ms
# 1084:	total: 1.12s	remaining: 947ms
# 1085:	total: 1.12s	remaining: 946ms
# 1086:	total: 1.13s	remaining: 945ms
# 1087:	total: 1.13s	remaining: 944ms
# 1088:	total: 1.13s	remaining: 943ms
# 1089:	total: 1.13s	remaining: 942ms
# 1090:	total: 1.13s	remaining: 941ms
# 1091:	total: 1.13s	remaining: 940ms
# 1092:	total: 1.13s	remaining: 939ms
# 1093:	total: 1.13s	remaining: 938ms
# 1094:	total: 1.13s	remaining: 937ms
# 1095:	total: 1.13s	remaining: 936ms
# 1096:	total: 1.14s	remaining: 935ms
# 1097:	total: 1.14s	remaining: 934ms
# 1098:	total: 1.14s	remaining: 933ms
# 1099:	total: 1.14s	remaining: 932ms
# 1100:	total: 1.14s	remaining: 931ms
# 1101:	total: 1.14s	remaining: 929ms
# 1102:	total: 1.14s	remaining: 928ms
# 1103:	total: 1.14s	remaining: 927ms
# 1104:	total: 1.14s	remaining: 926ms
# 1105:	total: 1.14s	remaining: 925ms
# 1106:	total: 1.15s	remaining: 924ms
# 1107:	total: 1.15s	remaining: 923ms
# 1108:	total: 1.15s	remaining: 922ms
# 1109:	total: 1.15s	remaining: 921ms
# 1110:	total: 1.15s	remaining: 920ms
# 1111:	total: 1.15s	remaining: 919ms
# 1112:	total: 1.15s	remaining: 918ms
# 1113:	total: 1.15s	remaining: 917ms
# 1114:	total: 1.15s	remaining: 916ms
# 1115:	total: 1.15s	remaining: 915ms
# 1116:	total: 1.16s	remaining: 914ms
# 1117:	total: 1.16s	remaining: 913ms
# 1118:	total: 1.16s	remaining: 912ms
# 1119:	total: 1.16s	remaining: 911ms
# 1120:	total: 1.16s	remaining: 909ms
# 1121:	total: 1.16s	remaining: 908ms
# 1122:	total: 1.16s	remaining: 907ms
# 1123:	total: 1.16s	remaining: 907ms
# 1124:	total: 1.16s	remaining: 906ms
# 1125:	total: 1.17s	remaining: 905ms
# 1126:	total: 1.17s	remaining: 904ms
# 1127:	total: 1.17s	remaining: 903ms
# 1128:	total: 1.17s	remaining: 902ms
# 1129:	total: 1.17s	remaining: 901ms
# 1130:	total: 1.17s	remaining: 899ms
# 1131:	total: 1.17s	remaining: 898ms
# 1132:	total: 1.17s	remaining: 897ms
# 1133:	total: 1.17s	remaining: 896ms
# 1134:	total: 1.17s	remaining: 895ms
# 1135:	total: 1.18s	remaining: 894ms
# 1136:	total: 1.18s	remaining: 893ms
# 1137:	total: 1.18s	remaining: 892ms
# 1138:	total: 1.18s	remaining: 891ms
# 1139:	total: 1.18s	remaining: 890ms
# 1140:	total: 1.18s	remaining: 889ms
# 1141:	total: 1.18s	remaining: 888ms
# 1142:	total: 1.18s	remaining: 887ms
# 1143:	total: 1.18s	remaining: 886ms
# 1144:	total: 1.18s	remaining: 884ms
# 1145:	total: 1.19s	remaining: 883ms
# 1146:	total: 1.19s	remaining: 882ms
# 1147:	total: 1.19s	remaining: 881ms
# 1148:	total: 1.19s	remaining: 880ms
# 1149:	total: 1.19s	remaining: 879ms
# 1150:	total: 1.19s	remaining: 878ms
# 1151:	total: 1.19s	remaining: 877ms
# 1152:	total: 1.19s	remaining: 876ms
# 1153:	total: 1.19s	remaining: 875ms
# 1154:	total: 1.19s	remaining: 874ms
# 1155:	total: 1.2s	remaining: 873ms
# 1156:	total: 1.2s	remaining: 872ms
# 1157:	total: 1.2s	remaining: 871ms
# 1158:	total: 1.2s	remaining: 870ms
# 1159:	total: 1.2s	remaining: 869ms
# 1160:	total: 1.2s	remaining: 870ms
# 1161:	total: 1.21s	remaining: 870ms
# 1162:	total: 1.21s	remaining: 869ms
# 1163:	total: 1.21s	remaining: 868ms
# 1164:	total: 1.21s	remaining: 867ms
# 1165:	total: 1.21s	remaining: 867ms
# 1166:	total: 1.22s	remaining: 867ms
# 1167:	total: 1.22s	remaining: 868ms
# 1168:	total: 1.22s	remaining: 867ms
# 1169:	total: 1.22s	remaining: 866ms
# 1170:	total: 1.22s	remaining: 865ms
# 1171:	total: 1.22s	remaining: 864ms
# 1172:	total: 1.22s	remaining: 863ms
# 1173:	total: 1.22s	remaining: 862ms
# 1174:	total: 1.23s	remaining: 861ms
# 1175:	total: 1.23s	remaining: 860ms
# 1176:	total: 1.23s	remaining: 859ms
# 1177:	total: 1.23s	remaining: 857ms
# 1178:	total: 1.23s	remaining: 856ms
# 1179:	total: 1.23s	remaining: 855ms
# 1180:	total: 1.23s	remaining: 854ms
# 1181:	total: 1.23s	remaining: 853ms
# 1182:	total: 1.23s	remaining: 852ms
# 1183:	total: 1.24s	remaining: 851ms
# 1184:	total: 1.24s	remaining: 850ms
# 1185:	total: 1.24s	remaining: 849ms
# 1186:	total: 1.24s	remaining: 848ms
# 1187:	total: 1.24s	remaining: 847ms
# 1188:	total: 1.24s	remaining: 846ms
# 1189:	total: 1.24s	remaining: 845ms
# 1190:	total: 1.24s	remaining: 844ms
# 1191:	total: 1.24s	remaining: 843ms
# 1192:	total: 1.24s	remaining: 842ms
# 1193:	total: 1.25s	remaining: 841ms
# 1194:	total: 1.25s	remaining: 840ms
# 1195:	total: 1.25s	remaining: 839ms
# 1196:	total: 1.25s	remaining: 838ms
# 1197:	total: 1.25s	remaining: 837ms
# 1198:	total: 1.25s	remaining: 836ms
# 1199:	total: 1.25s	remaining: 836ms
# 1200:	total: 1.26s	remaining: 836ms
# 1201:	total: 1.26s	remaining: 835ms
# 1202:	total: 1.26s	remaining: 834ms
# 1203:	total: 1.26s	remaining: 833ms
# 1204:	total: 1.26s	remaining: 832ms
# 1205:	total: 1.26s	remaining: 831ms
# 1206:	total: 1.26s	remaining: 830ms
# 1207:	total: 1.26s	remaining: 829ms
# 1208:	total: 1.26s	remaining: 828ms
# 1209:	total: 1.27s	remaining: 827ms
# 1210:	total: 1.27s	remaining: 826ms
# 1211:	total: 1.27s	remaining: 825ms
# 1212:	total: 1.27s	remaining: 824ms
# 1213:	total: 1.27s	remaining: 823ms
# 1214:	total: 1.27s	remaining: 821ms
# 1215:	total: 1.27s	remaining: 820ms
# 1216:	total: 1.27s	remaining: 819ms
# 1217:	total: 1.28s	remaining: 820ms
# 1218:	total: 1.28s	remaining: 820ms
# 1219:	total: 1.28s	remaining: 820ms
# 1220:	total: 1.28s	remaining: 820ms
# 1221:	total: 1.28s	remaining: 818ms
# 1222:	total: 1.29s	remaining: 819ms
# 1223:	total: 1.29s	remaining: 818ms
# 1224:	total: 1.29s	remaining: 817ms
# 1225:	total: 1.29s	remaining: 816ms
# 1226:	total: 1.29s	remaining: 815ms
# 1227:	total: 1.3s	remaining: 817ms
# 1228:	total: 1.3s	remaining: 816ms
# 1229:	total: 1.3s	remaining: 814ms
# 1230:	total: 1.3s	remaining: 813ms
# 1231:	total: 1.3s	remaining: 814ms
# 1232:	total: 1.31s	remaining: 814ms
# 1233:	total: 1.31s	remaining: 814ms
# 1234:	total: 1.31s	remaining: 813ms
# 1235:	total: 1.31s	remaining: 813ms
# 1236:	total: 1.32s	remaining: 812ms
# 1237:	total: 1.32s	remaining: 811ms
# 1238:	total: 1.32s	remaining: 810ms
# 1239:	total: 1.32s	remaining: 809ms
# 1240:	total: 1.32s	remaining: 808ms
# 1241:	total: 1.32s	remaining: 808ms
# 1242:	total: 1.33s	remaining: 809ms
# 1243:	total: 1.33s	remaining: 809ms
# 1244:	total: 1.33s	remaining: 809ms
# 1245:	total: 1.33s	remaining: 808ms
# 1246:	total: 1.34s	remaining: 807ms
# 1247:	total: 1.34s	remaining: 806ms
# 1248:	total: 1.34s	remaining: 805ms
# 1249:	total: 1.34s	remaining: 804ms
# 1250:	total: 1.34s	remaining: 803ms
# 1251:	total: 1.34s	remaining: 802ms
# 1252:	total: 1.34s	remaining: 801ms
# 1253:	total: 1.34s	remaining: 800ms
# 1254:	total: 1.34s	remaining: 799ms
# 1255:	total: 1.35s	remaining: 798ms
# 1256:	total: 1.35s	remaining: 797ms
# 1257:	total: 1.35s	remaining: 795ms
# 1258:	total: 1.35s	remaining: 794ms
# 1259:	total: 1.35s	remaining: 793ms
# 1260:	total: 1.35s	remaining: 792ms
# 1261:	total: 1.35s	remaining: 791ms
# 1262:	total: 1.35s	remaining: 790ms
# 1263:	total: 1.35s	remaining: 789ms
# 1264:	total: 1.35s	remaining: 788ms
# 1265:	total: 1.36s	remaining: 787ms
# 1266:	total: 1.36s	remaining: 785ms
# 1267:	total: 1.36s	remaining: 784ms
# 1268:	total: 1.36s	remaining: 783ms
# 1269:	total: 1.36s	remaining: 782ms
# 1270:	total: 1.36s	remaining: 781ms
# 1271:	total: 1.36s	remaining: 780ms
# 1272:	total: 1.36s	remaining: 779ms
# 1273:	total: 1.36s	remaining: 778ms
# 1274:	total: 1.36s	remaining: 777ms
# 1275:	total: 1.37s	remaining: 776ms
# 1276:	total: 1.37s	remaining: 774ms
# 1277:	total: 1.37s	remaining: 773ms
# 1278:	total: 1.37s	remaining: 772ms
# 1279:	total: 1.37s	remaining: 771ms
# 1280:	total: 1.37s	remaining: 770ms
# 1281:	total: 1.37s	remaining: 769ms
# 1282:	total: 1.37s	remaining: 768ms
# 1283:	total: 1.37s	remaining: 767ms
# 1284:	total: 1.38s	remaining: 766ms
# 1285:	total: 1.38s	remaining: 764ms
# 1286:	total: 1.38s	remaining: 763ms
# 1287:	total: 1.38s	remaining: 762ms
# 1288:	total: 1.38s	remaining: 761ms
# 1289:	total: 1.38s	remaining: 760ms
# 1290:	total: 1.38s	remaining: 759ms
# 1291:	total: 1.38s	remaining: 758ms
# 1292:	total: 1.38s	remaining: 757ms
# 1293:	total: 1.39s	remaining: 756ms
# 1294:	total: 1.39s	remaining: 755ms
# 1295:	total: 1.39s	remaining: 753ms
# 1296:	total: 1.39s	remaining: 752ms
# 1297:	total: 1.39s	remaining: 751ms
# 1298:	total: 1.39s	remaining: 750ms
# 1299:	total: 1.39s	remaining: 749ms
# 1300:	total: 1.39s	remaining: 748ms
# 1301:	total: 1.39s	remaining: 747ms
# 1302:	total: 1.39s	remaining: 746ms
# 1303:	total: 1.4s	remaining: 745ms
# 1304:	total: 1.4s	remaining: 744ms
# 1305:	total: 1.4s	remaining: 743ms
# 1306:	total: 1.4s	remaining: 741ms
# 1307:	total: 1.4s	remaining: 740ms
# 1308:	total: 1.4s	remaining: 739ms
# 1309:	total: 1.4s	remaining: 738ms
# 1310:	total: 1.4s	remaining: 737ms
# 1311:	total: 1.4s	remaining: 736ms
# 1312:	total: 1.4s	remaining: 735ms
# 1313:	total: 1.41s	remaining: 734ms
# 1314:	total: 1.41s	remaining: 733ms
# 1315:	total: 1.41s	remaining: 732ms
# 1316:	total: 1.41s	remaining: 730ms
# 1317:	total: 1.41s	remaining: 729ms
# 1318:	total: 1.41s	remaining: 728ms
# 1319:	total: 1.41s	remaining: 727ms
# 1320:	total: 1.41s	remaining: 726ms
# 1321:	total: 1.41s	remaining: 725ms
# 1322:	total: 1.41s	remaining: 724ms
# 1323:	total: 1.42s	remaining: 723ms
# 1324:	total: 1.42s	remaining: 722ms
# 1325:	total: 1.42s	remaining: 721ms
# 1326:	total: 1.42s	remaining: 719ms
# 1327:	total: 1.42s	remaining: 718ms
# 1328:	total: 1.42s	remaining: 717ms
# 1329:	total: 1.42s	remaining: 716ms
# 1330:	total: 1.42s	remaining: 715ms
# 1331:	total: 1.42s	remaining: 714ms
# 1332:	total: 1.42s	remaining: 713ms
# 1333:	total: 1.43s	remaining: 712ms
# 1334:	total: 1.43s	remaining: 711ms
# 1335:	total: 1.43s	remaining: 709ms
# 1336:	total: 1.43s	remaining: 708ms
# 1337:	total: 1.43s	remaining: 707ms
# 1338:	total: 1.43s	remaining: 706ms
# 1339:	total: 1.43s	remaining: 705ms
# 1340:	total: 1.43s	remaining: 704ms
# 1341:	total: 1.43s	remaining: 703ms
# 1342:	total: 1.43s	remaining: 702ms
# 1343:	total: 1.44s	remaining: 701ms
# 1344:	total: 1.44s	remaining: 700ms
# 1345:	total: 1.44s	remaining: 698ms
# 1346:	total: 1.44s	remaining: 697ms
# 1347:	total: 1.44s	remaining: 696ms
# 1348:	total: 1.44s	remaining: 695ms
# 1349:	total: 1.44s	remaining: 694ms
# 1350:	total: 1.44s	remaining: 693ms
# 1351:	total: 1.44s	remaining: 692ms
# 1352:	total: 1.44s	remaining: 691ms
# 1353:	total: 1.45s	remaining: 690ms
# 1354:	total: 1.45s	remaining: 689ms
# 1355:	total: 1.45s	remaining: 688ms
# 1356:	total: 1.45s	remaining: 687ms
# 1357:	total: 1.45s	remaining: 686ms
# 1358:	total: 1.45s	remaining: 684ms
# 1359:	total: 1.45s	remaining: 683ms
# 1360:	total: 1.45s	remaining: 682ms
# 1361:	total: 1.45s	remaining: 681ms
# 1362:	total: 1.46s	remaining: 680ms
# 1363:	total: 1.46s	remaining: 679ms
# 1364:	total: 1.46s	remaining: 678ms
# 1365:	total: 1.46s	remaining: 677ms
# 1366:	total: 1.46s	remaining: 676ms
# ...
# 1556:	total: 1.65s	remaining: 470ms
# 1557:	total: 1.65s	remaining: 469ms
# 1558:	total: 1.66s	remaining: 468ms
# 1559:	total: 1.66s	remaining: 467ms
# 1560:	total: 1.66s	remaining: 466ms
# 1561:	total: 1.66s	remaining: 465ms
# 1562:	total: 1.66s	remaining: 464ms
# 1563:	total: 1.66s	remaining: 463ms
# 1564:	total: 1.66s	remaining: 462ms
# 1565:	total: 1.66s	remaining: 461ms
# 1566:	total: 1.66s	remaining: 460ms
# 1567:	total: 1.66s	remaining: 459ms
# 1568:	total: 1.67s	remaining: 458ms
# 1569:	total: 1.67s	remaining: 457ms
# 1570:	total: 1.67s	remaining: 455ms
# 1571:	total: 1.67s	remaining: 454ms
# 1572:	total: 1.67s	remaining: 453ms
# 1573:	total: 1.67s	remaining: 452ms
# 1574:	total: 1.67s	remaining: 451ms
# 1575:	total: 1.67s	remaining: 450ms
# 1576:	total: 1.67s	remaining: 449ms
# 1577:	total: 1.67s	remaining: 448ms
# 1578:	total: 1.68s	remaining: 447ms
# 1579:	total: 1.68s	remaining: 446ms
# 1580:	total: 1.68s	remaining: 445ms
# 1581:	total: 1.68s	remaining: 444ms
# 1582:	total: 1.68s	remaining: 443ms
# 1583:	total: 1.68s	remaining: 441ms
# 1584:	total: 1.68s	remaining: 440ms
# 1585:	total: 1.68s	remaining: 439ms
# 1586:	total: 1.68s	remaining: 438ms
# 1587:	total: 1.69s	remaining: 437ms
# 1588:	total: 1.69s	remaining: 436ms
# 1589:	total: 1.69s	remaining: 435ms
# 1590:	total: 1.69s	remaining: 434ms
# 1591:	total: 1.69s	remaining: 433ms
# 1592:	total: 1.69s	remaining: 432ms
# 1593:	total: 1.69s	remaining: 431ms
# 1594:	total: 1.69s	remaining: 430ms
# 1595:	total: 1.69s	remaining: 429ms
# 1596:	total: 1.69s	remaining: 428ms
# 1597:	total: 1.7s	remaining: 426ms
# 1598:	total: 1.7s	remaining: 425ms
# 1599:	total: 1.7s	remaining: 424ms
# 1600:	total: 1.7s	remaining: 423ms
# 1601:	total: 1.7s	remaining: 422ms
# 1602:	total: 1.7s	remaining: 421ms
# 1603:	total: 1.7s	remaining: 420ms
# 1604:	total: 1.7s	remaining: 419ms
# 1605:	total: 1.7s	remaining: 418ms
# 1606:	total: 1.7s	remaining: 417ms
# 1607:	total: 1.71s	remaining: 416ms
# 1608:	total: 1.71s	remaining: 415ms
# 1609:	total: 1.71s	remaining: 414ms
# 1610:	total: 1.71s	remaining: 413ms
# 1611:	total: 1.71s	remaining: 412ms
# 1612:	total: 1.71s	remaining: 410ms
# 1613:	total: 1.71s	remaining: 409ms
# 1614:	total: 1.71s	remaining: 408ms
# 1615:	total: 1.71s	remaining: 407ms
# 1616:	total: 1.71s	remaining: 406ms
# 1617:	total: 1.72s	remaining: 405ms
# 1618:	total: 1.72s	remaining: 404ms
# 1619:	total: 1.72s	remaining: 403ms
# 1620:	total: 1.72s	remaining: 402ms
# 1621:	total: 1.72s	remaining: 401ms
# 1622:	total: 1.72s	remaining: 400ms
# 1623:	total: 1.72s	remaining: 399ms
# 1624:	total: 1.72s	remaining: 398ms
# 1625:	total: 1.72s	remaining: 397ms
# 1626:	total: 1.72s	remaining: 395ms
# 1627:	total: 1.73s	remaining: 394ms
# 1628:	total: 1.73s	remaining: 393ms
# 1629:	total: 1.73s	remaining: 392ms
# 1630:	total: 1.73s	remaining: 391ms
# 1631:	total: 1.73s	remaining: 390ms
# 1632:	total: 1.73s	remaining: 389ms
# 1633:	total: 1.73s	remaining: 388ms
# 1634:	total: 1.73s	remaining: 387ms
# 1635:	total: 1.73s	remaining: 386ms
# 1636:	total: 1.73s	remaining: 385ms
# 1637:	total: 1.74s	remaining: 384ms
# 1638:	total: 1.74s	remaining: 382ms
# 1639:	total: 1.74s	remaining: 381ms
# 1640:	total: 1.74s	remaining: 380ms
# 1641:	total: 1.74s	remaining: 379ms
# 1642:	total: 1.74s	remaining: 378ms
# 1643:	total: 1.74s	remaining: 377ms
# 1644:	total: 1.74s	remaining: 376ms
# 1645:	total: 1.74s	remaining: 375ms
# 1646:	total: 1.74s	remaining: 374ms
# 1647:	total: 1.75s	remaining: 373ms
# 1648:	total: 1.75s	remaining: 372ms
# 1649:	total: 1.75s	remaining: 371ms
# 1650:	total: 1.75s	remaining: 370ms
# 1651:	total: 1.75s	remaining: 369ms
# 1652:	total: 1.75s	remaining: 367ms
# 1653:	total: 1.75s	remaining: 366ms
# 1654:	total: 1.75s	remaining: 365ms
# 1655:	total: 1.75s	remaining: 364ms
# 1656:	total: 1.75s	remaining: 363ms
# 1657:	total: 1.75s	remaining: 362ms
# 1658:	total: 1.76s	remaining: 361ms
# 1659:	total: 1.76s	remaining: 360ms
# 1660:	total: 1.76s	remaining: 359ms
# 1661:	total: 1.76s	remaining: 358ms
# 1662:	total: 1.76s	remaining: 357ms
# 1663:	total: 1.76s	remaining: 356ms
# 1664:	total: 1.76s	remaining: 355ms
# 1665:	total: 1.76s	remaining: 353ms
# 1666:	total: 1.76s	remaining: 352ms
# 1667:	total: 1.76s	remaining: 351ms
# 1668:	total: 1.77s	remaining: 350ms
# 1669:	total: 1.77s	remaining: 349ms
# 1670:	total: 1.77s	remaining: 348ms
# 1671:	total: 1.77s	remaining: 347ms
# 1672:	total: 1.77s	remaining: 346ms
# 1673:	total: 1.77s	remaining: 345ms
# 1674:	total: 1.77s	remaining: 344ms
# 1675:	total: 1.77s	remaining: 343ms
# 1676:	total: 1.77s	remaining: 342ms
# 1677:	total: 1.77s	remaining: 341ms
# 1678:	total: 1.78s	remaining: 340ms
# 1679:	total: 1.78s	remaining: 338ms
# 1680:	total: 1.78s	remaining: 337ms
# 1681:	total: 1.78s	remaining: 336ms
# 1682:	total: 1.78s	remaining: 335ms
# 1683:	total: 1.78s	remaining: 334ms
# 1684:	total: 1.78s	remaining: 333ms
# 1685:	total: 1.78s	remaining: 332ms
# 1686:	total: 1.78s	remaining: 331ms
# 1687:	total: 1.78s	remaining: 330ms
# 1688:	total: 1.79s	remaining: 329ms
# 1689:	total: 1.79s	remaining: 328ms
# 1690:	total: 1.79s	remaining: 327ms
# 1691:	total: 1.79s	remaining: 326ms
# 1692:	total: 1.79s	remaining: 325ms
# 1693:	total: 1.79s	remaining: 324ms
# 1694:	total: 1.79s	remaining: 322ms
# 1695:	total: 1.79s	remaining: 321ms
# 1696:	total: 1.79s	remaining: 320ms
# 1697:	total: 1.79s	remaining: 319ms
# 1698:	total: 1.79s	remaining: 318ms
# 1699:	total: 1.8s	remaining: 317ms
# 1700:	total: 1.8s	remaining: 316ms
# 1701:	total: 1.8s	remaining: 315ms
# 1702:	total: 1.8s	remaining: 314ms
# 1703:	total: 1.8s	remaining: 313ms
# 1704:	total: 1.8s	remaining: 312ms
# 1705:	total: 1.8s	remaining: 311ms
# 1706:	total: 1.81s	remaining: 310ms
# 1707:	total: 1.81s	remaining: 309ms
# 1708:	total: 1.81s	remaining: 308ms
# 1709:	total: 1.81s	remaining: 307ms
# 1710:	total: 1.81s	remaining: 306ms
# 1711:	total: 1.81s	remaining: 305ms
# 1712:	total: 1.81s	remaining: 304ms
# 1713:	total: 1.82s	remaining: 303ms
# 1714:	total: 1.82s	remaining: 302ms
# 1715:	total: 1.82s	remaining: 301ms
# 1716:	total: 1.82s	remaining: 300ms
# 1717:	total: 1.82s	remaining: 299ms
# 1718:	total: 1.82s	remaining: 298ms
# 1719:	total: 1.83s	remaining: 297ms
# 1720:	total: 1.83s	remaining: 296ms
# 1721:	total: 1.83s	remaining: 295ms
# 1722:	total: 1.83s	remaining: 294ms
# 1723:	total: 1.83s	remaining: 293ms
# 1724:	total: 1.83s	remaining: 292ms
# 1725:	total: 1.83s	remaining: 291ms
# 1726:	total: 1.83s	remaining: 290ms
# 1727:	total: 1.83s	remaining: 289ms
# 1728:	total: 1.83s	remaining: 288ms
# 1729:	total: 1.84s	remaining: 287ms
# 1730:	total: 1.84s	remaining: 286ms
# 1731:	total: 1.84s	remaining: 284ms
# 1732:	total: 1.84s	remaining: 283ms
# 1733:	total: 1.84s	remaining: 282ms
# 1734:	total: 1.84s	remaining: 281ms
# 1735:	total: 1.84s	remaining: 280ms
# 1736:	total: 1.84s	remaining: 279ms
# 1737:	total: 1.84s	remaining: 278ms
# 1738:	total: 1.84s	remaining: 277ms
# 1739:	total: 1.84s	remaining: 276ms
# 1740:	total: 1.85s	remaining: 275ms
# 1741:	total: 1.85s	remaining: 274ms
# 1742:	total: 1.85s	remaining: 273ms
# 1743:	total: 1.85s	remaining: 272ms
# 1744:	total: 1.85s	remaining: 270ms
# 1745:	total: 1.85s	remaining: 269ms
# 1746:	total: 1.85s	remaining: 268ms
# 1747:	total: 1.85s	remaining: 267ms
# 1748:	total: 1.85s	remaining: 266ms
# 1749:	total: 1.85s	remaining: 265ms
# 1750:	total: 1.86s	remaining: 264ms
# 1751:	total: 1.86s	remaining: 263ms
# 1752:	total: 1.86s	remaining: 262ms
# 1753:	total: 1.86s	remaining: 261ms
# 1754:	total: 1.86s	remaining: 260ms
# 1755:	total: 1.86s	remaining: 259ms
# 1756:	total: 1.86s	remaining: 258ms
# 1757:	total: 1.86s	remaining: 257ms
# 1758:	total: 1.86s	remaining: 255ms
# 1759:	total: 1.86s	remaining: 254ms
# 1760:	total: 1.87s	remaining: 253ms
# 1761:	total: 1.87s	remaining: 252ms
# 1762:	total: 1.87s	remaining: 251ms
# 1763:	total: 1.87s	remaining: 250ms
# 1764:	total: 1.87s	remaining: 249ms
# 1765:	total: 1.87s	remaining: 248ms
# 1766:	total: 1.87s	remaining: 247ms
# 1767:	total: 1.87s	remaining: 246ms
# 1768:	total: 1.87s	remaining: 245ms
# 1769:	total: 1.88s	remaining: 244ms
# 1770:	total: 1.88s	remaining: 243ms
# 1771:	total: 1.88s	remaining: 242ms
# 1772:	total: 1.88s	remaining: 240ms
# 1773:	total: 1.88s	remaining: 239ms
# 1774:	total: 1.88s	remaining: 238ms
# 1775:	total: 1.88s	remaining: 237ms
# 1776:	total: 1.88s	remaining: 236ms
# 1777:	total: 1.88s	remaining: 235ms
# 1778:	total: 1.88s	remaining: 234ms
# 1779:	total: 1.89s	remaining: 233ms
# 1780:	total: 1.89s	remaining: 232ms
# 1781:	total: 1.89s	remaining: 231ms
# 1782:	total: 1.89s	remaining: 230ms
# 1783:	total: 1.89s	remaining: 229ms
# 1784:	total: 1.89s	remaining: 228ms
# 1785:	total: 1.89s	remaining: 227ms
# 1786:	total: 1.89s	remaining: 225ms
# 1787:	total: 1.89s	remaining: 224ms
# 1788:	total: 1.89s	remaining: 223ms
# 1789:	total: 1.89s	remaining: 222ms
# 1790:	total: 1.9s	remaining: 221ms
# 1791:	total: 1.9s	remaining: 220ms
# 1792:	total: 1.9s	remaining: 219ms
# 1793:	total: 1.9s	remaining: 218ms
# 1794:	total: 1.9s	remaining: 217ms
# 1795:	total: 1.9s	remaining: 216ms
# 1796:	total: 1.9s	remaining: 215ms
# 1797:	total: 1.9s	remaining: 214ms
# 1798:	total: 1.9s	remaining: 213ms
# 1799:	total: 1.9s	remaining: 212ms
# 1800:	total: 1.91s	remaining: 211ms
# 1801:	total: 1.91s	remaining: 209ms
# 1802:	total: 1.91s	remaining: 208ms
# 1803:	total: 1.91s	remaining: 207ms
# 1804:	total: 1.91s	remaining: 206ms
# 1805:	total: 1.91s	remaining: 205ms
# 1806:	total: 1.91s	remaining: 204ms
# 1807:	total: 1.91s	remaining: 203ms
# 1808:	total: 1.91s	remaining: 202ms
# 1809:	total: 1.91s	remaining: 201ms
# 1810:	total: 1.92s	remaining: 200ms
# 1811:	total: 1.92s	remaining: 199ms
# 1812:	total: 1.92s	remaining: 198ms
# 1813:	total: 1.92s	remaining: 197ms
# 1814:	total: 1.92s	remaining: 196ms
# 1815:	total: 1.92s	remaining: 195ms
# 1816:	total: 1.92s	remaining: 193ms
# 1817:	total: 1.92s	remaining: 192ms
# 1818:	total: 1.92s	remaining: 191ms
# 1819:	total: 1.92s	remaining: 190ms
# 1820:	total: 1.92s	remaining: 189ms
# 1821:	total: 1.93s	remaining: 188ms
# 1822:	total: 1.93s	remaining: 187ms
# 1823:	total: 1.93s	remaining: 186ms
# 1824:	total: 1.93s	remaining: 185ms
# 1825:	total: 1.93s	remaining: 184ms
# 1826:	total: 1.93s	remaining: 183ms
# 1827:	total: 1.93s	remaining: 182ms
# 1828:	total: 1.93s	remaining: 181ms
# 1829:	total: 1.93s	remaining: 180ms
# 1830:	total: 1.93s	remaining: 179ms
# 1831:	total: 1.94s	remaining: 177ms
# 1832:	total: 1.94s	remaining: 176ms
# 1833:	total: 1.94s	remaining: 175ms
# 1834:	total: 1.94s	remaining: 174ms
# 1835:	total: 1.94s	remaining: 173ms
# 1836:	total: 1.94s	remaining: 172ms
# 1837:	total: 1.94s	remaining: 171ms
# 1838:	total: 1.94s	remaining: 170ms
# 1839:	total: 1.94s	remaining: 169ms
# 1840:	total: 1.94s	remaining: 168ms
# 1841:	total: 1.95s	remaining: 167ms
# 1842:	total: 1.95s	remaining: 166ms
# 1843:	total: 1.95s	remaining: 165ms
# 1844:	total: 1.95s	remaining: 164ms
# 1845:	total: 1.95s	remaining: 163ms
# 1846:	total: 1.95s	remaining: 162ms
# 1847:	total: 1.95s	remaining: 161ms
# 1848:	total: 1.95s	remaining: 159ms
# 1849:	total: 1.95s	remaining: 158ms
# 1850:	total: 1.95s	remaining: 157ms
# 1851:	total: 1.96s	remaining: 156ms
# 1852:	total: 1.96s	remaining: 155ms
# 1853:	total: 1.96s	remaining: 154ms
# 1854:	total: 1.96s	remaining: 153ms
# 1855:	total: 1.96s	remaining: 152ms
# 1856:	total: 1.96s	remaining: 151ms
# 1857:	total: 1.96s	remaining: 150ms
# 1858:	total: 1.96s	remaining: 149ms
# 1859:	total: 1.96s	remaining: 148ms
# 1860:	total: 1.96s	remaining: 147ms
# 1861:	total: 1.97s	remaining: 146ms
# 1862:	total: 1.97s	remaining: 145ms
# 1863:	total: 1.97s	remaining: 144ms
# 1864:	total: 1.97s	remaining: 143ms
# 1865:	total: 1.97s	remaining: 141ms
# 1866:	total: 1.97s	remaining: 140ms
# 1867:	total: 1.97s	remaining: 139ms
# 1868:	total: 1.97s	remaining: 138ms
# 1869:	total: 1.97s	remaining: 137ms
# 1870:	total: 1.97s	remaining: 136ms
# 1871:	total: 1.98s	remaining: 135ms
# 1872:	total: 1.98s	remaining: 134ms
# 1873:	total: 1.98s	remaining: 133ms
# 1874:	total: 1.98s	remaining: 132ms
# 1875:	total: 1.98s	remaining: 131ms
# 1876:	total: 1.98s	remaining: 130ms
# 1877:	total: 1.98s	remaining: 129ms
# 1878:	total: 1.98s	remaining: 128ms
# 1879:	total: 1.98s	remaining: 127ms
# 1880:	total: 1.98s	remaining: 126ms
# 1881:	total: 1.99s	remaining: 125ms
# 1882:	total: 1.99s	remaining: 123ms
# 1883:	total: 1.99s	remaining: 122ms
# 1884:	total: 1.99s	remaining: 121ms
# 1885:	total: 1.99s	remaining: 120ms
# 1886:	total: 1.99s	remaining: 119ms
# 1887:	total: 1.99s	remaining: 118ms
# 1888:	total: 1.99s	remaining: 117ms
# 1889:	total: 1.99s	remaining: 116ms
# 1890:	total: 2s	remaining: 115ms
# 1891:	total: 2s	remaining: 114ms
# 1892:	total: 2s	remaining: 113ms
# 1893:	total: 2s	remaining: 112ms
# 1894:	total: 2s	remaining: 111ms
# 1895:	total: 2s	remaining: 110ms
# 1896:	total: 2s	remaining: 109ms
# 1897:	total: 2s	remaining: 108ms
# 1898:	total: 2.01s	remaining: 107ms
# 1899:	total: 2.01s	remaining: 106ms
# 1900:	total: 2.01s	remaining: 105ms
# 1901:	total: 2.01s	remaining: 104ms
# 1902:	total: 2.01s	remaining: 102ms
# 1903:	total: 2.01s	remaining: 101ms
# 1904:	total: 2.01s	remaining: 100ms
# 1905:	total: 2.01s	remaining: 99.3ms
# 1906:	total: 2.01s	remaining: 98.2ms
# 1907:	total: 2.02s	remaining: 97.2ms
# 1908:	total: 2.02s	remaining: 96.1ms
# 1909:	total: 2.02s	remaining: 95ms
# 1910:	total: 2.02s	remaining: 94ms
# 1911:	total: 2.02s	remaining: 92.9ms
# 1912:	total: 2.02s	remaining: 91.9ms
# 1913:	total: 2.02s	remaining: 90.8ms
# 1914:	total: 2.02s	remaining: 89.8ms
# 1915:	total: 2.02s	remaining: 88.7ms
# 1916:	total: 2.02s	remaining: 87.6ms
# 1917:	total: 2.02s	remaining: 86.6ms
# 1918:	total: 2.03s	remaining: 85.5ms
# 1919:	total: 2.03s	remaining: 84.5ms
# 1920:	total: 2.03s	remaining: 83.4ms
# 1921:	total: 2.03s	remaining: 82.4ms
# 1922:	total: 2.03s	remaining: 81.3ms
# 1923:	total: 2.03s	remaining: 80.2ms
# 1924:	total: 2.03s	remaining: 79.2ms
# 1925:	total: 2.03s	remaining: 78.1ms
# 1926:	total: 2.03s	remaining: 77.1ms
# 1927:	total: 2.04s	remaining: 76ms
# 1928:	total: 2.04s	remaining: 74.9ms
# 1929:	total: 2.04s	remaining: 73.9ms
# 1930:	total: 2.04s	remaining: 72.8ms
# 1931:	total: 2.04s	remaining: 71.8ms
# 1932:	total: 2.04s	remaining: 70.7ms
# 1933:	total: 2.04s	remaining: 69.6ms
# 1934:	total: 2.04s	remaining: 68.6ms
# 1935:	total: 2.04s	remaining: 67.5ms
# 1936:	total: 2.04s	remaining: 66.5ms
# 1937:	total: 2.04s	remaining: 65.4ms
# 1938:	total: 2.04s	remaining: 64.4ms
# 1939:	total: 2.05s	remaining: 63.3ms
# 1940:	total: 2.05s	remaining: 62.2ms
# 1941:	total: 2.05s	remaining: 61.2ms
# 1942:	total: 2.05s	remaining: 60.1ms
# 1943:	total: 2.05s	remaining: 59.1ms
# 1944:	total: 2.05s	remaining: 58ms
# 1945:	total: 2.05s	remaining: 57ms
# 1946:	total: 2.05s	remaining: 55.9ms
# 1947:	total: 2.05s	remaining: 54.8ms
# 1948:	total: 2.06s	remaining: 53.8ms
# 1949:	total: 2.06s	remaining: 52.7ms
# 1950:	total: 2.06s	remaining: 51.7ms
# 1951:	total: 2.06s	remaining: 50.6ms
# 1952:	total: 2.06s	remaining: 49.6ms
# 1953:	total: 2.06s	remaining: 48.5ms
# 1954:	total: 2.06s	remaining: 47.4ms
# 1955:	total: 2.06s	remaining: 46.4ms
# 1956:	total: 2.06s	remaining: 45.3ms
# 1957:	total: 2.06s	remaining: 44.3ms
# 1958:	total: 2.06s	remaining: 43.2ms
# 1959:	total: 2.07s	remaining: 42.2ms
# 1960:	total: 2.07s	remaining: 41.1ms
# 1961:	total: 2.07s	remaining: 40.1ms
# 1962:	total: 2.07s	remaining: 39ms
# 1963:	total: 2.07s	remaining: 37.9ms
# 1964:	total: 2.07s	remaining: 36.9ms
# 1965:	total: 2.07s	remaining: 35.8ms
# 1966:	total: 2.07s	remaining: 34.8ms
# 1967:	total: 2.07s	remaining: 33.7ms
# 1968:	total: 2.07s	remaining: 32.7ms
# 1969:	total: 2.08s	remaining: 31.6ms
# 1970:	total: 2.08s	remaining: 30.6ms
# 1971:	total: 2.08s	remaining: 29.5ms
# 1972:	total: 2.08s	remaining: 28.4ms
# 1973:	total: 2.08s	remaining: 27.4ms
# 1974:	total: 2.08s	remaining: 26.3ms
# 1975:	total: 2.08s	remaining: 25.3ms
# 1976:	total: 2.08s	remaining: 24.2ms
# 1977:	total: 2.08s	remaining: 23.2ms
# 1978:	total: 2.08s	remaining: 22.1ms
# 1979:	total: 2.08s	remaining: 21.1ms
# 1980:	total: 2.09s	remaining: 20ms
# 1981:	total: 2.09s	remaining: 19ms
# 1982:	total: 2.09s	remaining: 17.9ms
# 1983:	total: 2.09s	remaining: 16.8ms
# 1984:	total: 2.09s	remaining: 15.8ms
# 1985:	total: 2.09s	remaining: 14.7ms
# 1986:	total: 2.09s	remaining: 13.7ms
# 1987:	total: 2.09s	remaining: 12.6ms
# 1988:	total: 2.09s	remaining: 11.6ms
# 1989:	total: 2.09s	remaining: 10.5ms
# 1990:	total: 2.1s	remaining: 9.47ms
# 1991:	total: 2.1s	remaining: 8.42ms
# 1992:	total: 2.1s	remaining: 7.37ms
# 1993:	total: 2.1s	remaining: 6.32ms
# 1994:	total: 2.1s	remaining: 5.26ms
# 1995:	total: 2.1s	remaining: 4.21ms
# 1996:	total: 2.1s	remaining: 3.16ms
# 1997:	total: 2.1s	remaining: 2.1ms
# 1998:	total: 2.1s	remaining: 1.05ms
# 1999:	total: 2.1s	remaining: 0us

# %%
y_pred = cat.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[389  98]
#  [ 40 222]]
# 0.8157543391188251
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.80      0.85       487
#          1.0       0.69      0.85      0.76       262
#
#     accuracy                           0.82       749
#    macro avg       0.80      0.82      0.81       749
# weighted avg       0.83      0.82      0.82       749

# %%
from sklearn import metrics
metrics.plot_roc_curve(cat, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# /home/unknown/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 0.8230481057102998

# %%
joblib.dump(rf, "rf.pkl")
joblib.dump(logreg, "logreg.pkl")
joblib.dump(gnb, "gnb.pkl")
joblib.dump(knn, "knn.pkl")
joblib.dump(svc, "svc.pkl")
joblib.dump(bst, "xgb.pkl")
joblib.dump(svc, "cat.pkl")
# Out:
# ['cat.pkl']
